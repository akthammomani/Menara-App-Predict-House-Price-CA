# %% [markdown]
# # 1 Data wrangling<a id='2_Data_wrangling'></a>
#
# ![Data_Wrangling_hh](https://user-images.githubusercontent.com/67468718/104858187-6ec96180-58d2-11eb-8e6e-f110ef5193fb.JPG)

# %% [markdown]
# ## 1.1 Contents<a id='1.1_Contents'></a>
# * [1 Data wrangling](#2_Data_wrangling)
#   * [1.1 Contents](#1.1_Contents)
#   * [1.2 Introduction](#1.2_Introduction)
#   * [1.3 Imports](#1.3_Imports)
#   * [1.4 Data Wrangling Objectives](#1.4_Data_Wrangling_Objectives)
#   * [1.5 Load the 8 DataSets](#1.5_Load_the_8_DataSets)
#     * [1.5.1 df_median_income wrangling](#1.5.1_df_median_income_wrangling)
#       * [1.5.1.1 df_median_income Wrangling Summary](#1.5.1.1_df_median_income_Wrangling_Summary)
#       * [1.5.1.2 Imputing NANs, Wrong Values and Duplicates](#1.5.1.2_Imputing_NANs_Wrong_Values_and_Duplicates)
#       * [1.5.1.3 Converting Dataset](#1.5.1.3_Converting_Dataset)
#       * [1.5.1.4 Correcting Data Types](#1.5.1.4_Correcting_Data_Types)
#       * [1.5.1.5 Drop Insignificant Columns](#1.5.1.5_Drop_Insignificant_Columns)
#       * [1.5.1.6 Visualization](#1.5.1.6_Visualization)
#       * [1.5.1.7 Saving Cleaned df](#1.5.1.7_Saving_Cleaned_df)
#     * [1.5.2 df_malls wrangling](#1.5.2_df_malls_wrangling)
#       * [1.5.2.1 df_malls Wrangling Summary](#1.5.2.1_df_malls_Wrangling_Summary)
#       * [1.5.2.2 Imputing NANs, Wrong Values and Duplicates](#1.5.2.2_Imputing_NANs_Wrong_Values_and_Duplicates)
#       * [1.5.2.3 Renaming Columns](#1.5.2.3_Renaming_Columns)
#       * [1.5.2.4 Visualization](#1.5.2.4_Visualization)
#       * [1.5.2.5 Lowercase And Remove Spaces from Columns](#1.5.2.5_Lowercase_And_Remove_Spaces_from_Columns)
#       * [1.5.2.6 Saving Cleaned df](#1.5.2.6_Saving_Cleaned_df)
#     * [1.5.3 df_universities wrangling](#1.5.3_df_universities_wrangling)
#       * [1.5.3.1 df_universities Wrangling Summary](#1.5.3.1_df_universities_Wrangling_Summary)
#       * [1.5.3.2 Imputing NANs, Wrong Values and Duplicates](#[1.5.3.2_Imputing_NANs_Wrong_Values_and_Duplicates)
#       * [1.5.3.3 Renaming Columns](#1.5.3.3_Renaming_Columns)
#       * [1.5.3.4 Drop Insignificant Columns](#1.5.3.4_Drop_Insignificant_Columns)
#       * [1.5.3.5 Group By On City](#1.5.3.5_Group_By_On_City)
#       * [1.5.3.6 Lowercase City Column](#1.5.3.6_Lowercase_City_Column)
#       * [1.5.3.7 Visualization](#1.5.3.7_Visualization)
#       * [1.5.3.8 Saving Cleaned df](#1.5.3.8_Saving_Cleaned_df)
#     * [1.5.4 df_greatschools wrangling](#1.5.4_df_greatschools_wrangling)
#       * [1.5.4.1 df_greatschools Wrangling Summary](#1.5.4.1_df_greatschools_Wrangling_Summary)
#       * [1.5.4.2 Drop Insignificant Columns](#1.5.4.2_Drop_Insignificant_Columns)
#       * [1.5.4.3 Renaming Columns](#1.5.4.3_Renaming_Columns)
#       * [1.5.4.4 Imputing NANs, Wrong Values and Duplicates](#1.5.4.4_Imputing_NANs_Wrong_Values_and_Duplicates)
#       * [1.5.4.5 Correcting Data Types](#1.5.4.5_Correcting_Data_Types)
#       * [1.5.4.6 Lowercase City Column](#1.5.4.6_Lowercase_City_Column)
#       * [1.5.4.7 Visualization](#1.5.4.7_Visualization)
#       * [1.5.4.8 Saving Cleaned df](#1.5.4.8_Saving_Cleaned_df)
#     * [1.5.5 df_bart wrangling](#1.5.5_df_bart_wrangling)
#       * [1.5.5.1 df_bart Wrangling Summary](#1.5.5.1_df_bart_Wrangling_Summary)
#       * [1.5.5.2 Imputing NANs, Wrong Values and Duplicates](#1.5.5.2_Imputing_NANs_Wrong_Values_and_Duplicates)
#       * [1.5.5.3 Group By On Zipcode](#1.5.5.3_Group_By_On_Zipcode)
#       * [1.5.5.4 Renaming Columns](#1.5.5.4_Renaming_Columns)
#       * [1.5.5.5 Saving Cleaned df](#1.5.5.5_Saving_Cleaned_df)
#     * [1.5.6 df_publichschools wrangling](#1.5.6_df_publichschools_wrangling)
#       * [1.5.6.1 df_publichschools Wrangling Summary](#1.5.6.1_df_publichschools_Wrangling_Summary)
#       * [1.5.6.2 Drop Insignificant Columns](#1.5.6.2_Drop_Insignificant_Columns)
#       * [1.5.6.3 Correcting Data Types](#1.5.6.3_Correcting_Data_Types)
#       * [1.5.6.4 Renaming Columns](#1.5.6.4_Renaming_Columns)
#       * [1.5.6.5 Merge df_greatschools & df_publichschools ON ncesId](#1.5.6.5_Merge_df_greatschools_&_df_publichschools_ON_ncesId)
#       * [1.5.6.6 Group By to get a new df with zipcode & gsRating](#1.5.6.6_Group_By_to_get_a_new_df_with_zipcode_&_gsRating)
#       * [1.5.6.7 Round gsRating](#1.5.6.7_Round_gsRating)
#       * [1.5.6.8 Correcting Data Types in avg_gsRating_zipcode_final](#1.5.6.8_Correcting_Data_Types_in_avg_gsRating_zipcode_final)
#       * [1.5.6.9 Renaming Columns in avg_gsRating_zipcode_final](#1.5.6.9_Renaming_Columns_in_avg_gsRating_zipcode_final)
#       * [1.5.6.10 Group By to get a new df with zipcode & school_count](#1.5.6.10_Group_By_to_get_a_new_df_with_zipcode_&_gsRating)
#       * [1.5.6.11 Renaming Columns in School_count_zipcode](#1.5.6.11_Renaming_Columns_in_School_count_zipcode)
#       * [1.5.6.12 Merge avg_gsRating_zipcode_final & School_count_zipcode on Zipcode](#1.5.6.12_Merge_avg_gsRating_zipcode_final_&_School_count_zipcode_on_Zipcode)
#       * [1.5.6.13 Saving Cleaned df](#1.5.6.13_Saving_Cleaned_df)
#     * [1.5.7 df_hotness wrangling](#1.5.7_df_hotness_wrangling)
#       * [1.5.7.1 df_publichschools Wrangling Summary](#1.5.7.1_df_publichschools_Wrangling_Summary)
#       * [1.5.7.2 Drop Insignificant Columns](#1.5.7.2_Drop_Insignificant_Columns)
#       * [1.5.7.3 Filter df_hotness to have only latest 12 Months](#1.5.7.3_Filter_df_hotness_to_have_only_latest_12_Months)
#       * [1.5.7.4 Group by on zipcode to have avg_score_per_year](#1.5.7.4_Group_by-on_zipcode_to_have_avg_score_per_year)
#       * [1.5.7.5 Round Columns](#1.5.7.5_Round_Columns)
#       * [1.5.7.6 Renaming Columns in avg_score_per_year](#1.5.7.6_Renaming_Columns_in_avg_score_per_year)
#       * [1.5.7.7 Saving Cleaned df](#1.5.7.7_Saving_Cleaned_df)
#     * [1.5.8 df_main_sold_houses wrangling](#1.5.8_df_main_sold_houses_wrangling)
#       * [1.5.8.1 df_main_sold_houses Wrangling Summary](#1.5.8.1_df_main_sold_houses_Wrangling_Summary)
#       * [1.5.8.2 Drop Insignificant Columns](#1.5.8.2_Drop_Insignificant_Columns)
#       * [1.5.8.3 Imputing NANs and Wrong Values](#1.5.8.3_Imputing_NANs_Wrong_Values)
#       * [1.5.8.4 Replacing Year Built Column with propert_age](#1.5.8.4_Replacing_YearBuilt_Column_with_propert_age)
#       * [1.5.8.5 Round Columns](#1.5.8.5_Round_Columns)
#       * [1.5.8.6 Correcting Data Types](#1.5.8.6_Correcting_Data_Types)
#       * [1.5.8.7 Dealing with Duplicates](#1.5.8.7_Dealing_with_Duplicates)
#       * [1.5.8.8 Renaming Columns](#1.5.8.8_Renaming_Columns)
#       * [1.5.8.9 Saving Cleaned df](#1.5.8.9_Saving_Cleaned_df)
#   * [1.6 Merging 7 DataFrames](#1.6_Merging_7_DataFrames)
#     * [1.6.1 Merge Summary](#1.6.1_Merge_Summary)
#     * [1.6.2 Merge dfs on zipcode](#1.6.2_Merge_dfs_on_zipcode)
#     * [1.6.3 Merge dfs on city](#1.6.3_Merge_dfs_on_city)
#     * [1.6.4 Imputing NANs and Wrong Values](#1.6.4_Imputing_NANs_Wrong_Values)
#     * [1.6.5 Correcting Data Types](#1.6.5_Correcting_Data_Types)
#     * [1.6.6 Saving Final df](#1.6.6_Saving_Final_df)
#     * [1.6.7 Visualization](#1.6.7_Visualization)
#   * [1.7 Target Features](#1.7_Target_Features)

# %% [markdown]
# ## 1.2 Introduction<a id='1.2_Introduction'></a>
#
#
#
# ### The Data wrangling step focuses on collecting our data, organizing it, and making sure it's well defined. For our project we have collected below datasets to have a good foundation to build a Machine Learning model where we can provide a good estimate of house prices in North California:
#
# 1. Main Dataset: Source www.redfin.com:
#     * Obtained sold houses from Dec 2019-Dec 2020.
#     * The sold houses located in North California distributed between 49 cities and 94 Zip Codes.
#     * Data has 8,790 Observations and 27 Variables.
#
#
#
# 2. Adding Median Income per Zip code:
#     * Source: http://www.usa.com/rank/california-state--median-household-income--zip-code-rank.htm and since the data from 2010-2014, and according to https://www.statista.com/statistics --> the median Income in California has grown by 6.36% we’ll use this % to adjust this Dataset YoY.
#
#
# 3. Adding Hotness score (0-100) to refelect the demand and supply per zip code:
#     * Source: https://www.realtor.com/research/data/
#
#
# 4. Adding Public School per zip code:
#     * Source: https://hifld-geoplatform.opendata.arcgis.com/datasets/87376bdb0cb3490cbda39935626f6604_0
#
#
# 5. Adding GreatSchools Rating to reflect Schools rating in all the selected 47 cities in North California:
#     * Source: GreatSchools.org API https://www.greatschools.org/api/request-api-key
#
#
# 6. Adding Shoping and Mall centers in CA per city:
#     * Source: https://en.wikipedia.org/wiki/List_of_shopping_malls_in_California
#
#
# 7. Adding Universities and colleges list in CA per city:
#     * Source: http://www.free-4u.com/Colleges/California-Colleges.html
#
#
# 8. Adding BART (Bay Area Rapid Transit) stations with parking (Y/N) per zip code in North California:
#     * Source: https://www.bart.gov/stations

# %% [markdown]
# ## 1.3 Imports<a id='1.3_Imports'></a>

# %%
#let's import below packages:

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os 
from sb_utils import save_file

# %% [markdown]
# ## 1.4 Data Wrangling Objectives<a id='1.4_Data_Wrangling_Objectives'></a>
#
# #### We have 8 Datasets to support this project, so we'll focus in below:
#    * Clean NANs, duplicate values, wrong values and removing insignificant columns.
#    * Merging and concatenation will be needed.
#    * The GreatSchools API is a REST-based web service (**Completed**): will need to use Python Packages: requests, xml.etree.ElementTree and glob:
#         - requests: To request the data from GreatSchools API
#         - xml.etree.ElementTree module : to implement a simple and efficient API for parsing and creating XML data.
#         - glob: to concatenate all the API output in one final DataFrame.
#    * **Data Wrangling layout and the Initial DataFrame structure**: at this stage we'll not be overzealous in our cleaning because we need to explore the data to better understand it in the exploratory data analysis Stage (EDA) where we'll provide the final datframe Structure.

# %% [markdown]
# ## 1.5 Load the 8 DataSets<a id='1.5_Load_the_8_DataSets'></a>

# %%
# First let's find current Directory:
os.getcwd()

# %%
# Changing the directory:
os.chdir(r"path/capstone_two_House_Prices/Datasets")

# %%
#Confirm the directory:
os.getcwd()

# %%
# let's list all the Datasets we need to load for this project: filenames
filenames = os.listdir()
filenames
# Out:
# ['California_Median_Household_Income_Zip.csv',
#  'CA_List_Malls_Shopping_Center_per_City.csv',
#  'CA_universities_list.csv',
#  'GreatSchools_NCA_df.csv',
#  'NCA_BART_Stations.csv',
#  'Public_Schools_CA.csv',
#  'RDC_Inventory_Hotness_Metrics_Zip_NCAL.csv',
#  'redfin_sold_House_Dec2019_Dec2020.csv']

# %%
# Confirm the datasets_count:Datasets_count
Datasets_count = len(filenames)
Datasets_count
# Out:
# 8

# %%
# let's read all these Datasets: 
import pandas as pd

filenames = ['California_Median_Household_Income_Zip.csv',
 'CA_List_Malls_Shopping_Center_per_City.csv',
 'CA_universities_list.csv',
 'GreatSchools_NCA_df.csv',
 'NCA_BART_Stations.csv',
 'Public_Schools_CA.csv',
 'RDC_Inventory_Hotness_Metrics_Zip_NCAL.csv',
 'redfin_sold_House_Dec2019_Dec2020.csv']

dataframes =[]

for f in filenames:
    dataframes.append(pd.read_csv(f, encoding='ISO-8859-1'))

# %%
#let's rename the dataframes according to the above filenames list:
df_median_income = dataframes[0]
df_malls = dataframes[1]
df_universities = dataframes[2]
df_greatschools = dataframes[3]
df_bart = dataframes[4]
df_publichschools = dataframes[5]
df_hotness = dataframes[6]
df_main_sold_houses = dataframes[7]

# %% [markdown]
# ### For our project we need to wrangle all these 8 dataframes and get finally a single cleaned dataframe as follows:
#
# ![Data_Wrangling_initial](https://user-images.githubusercontent.com/67468718/103534919-a7822900-4e44-11eb-9f68-c6124e66bbd1.JPG)

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# Out:
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }

# %% [markdown]
# ### 1.5.1 df_median_income wrangling<a id='1.5.1_df_median_income_wrangling'></a>

# %%
df_median_income.head()
# Out:
#    Rank  Median Household Income    Zip   Population
# 0     1                   236912  94027        7,230
# 1     2                   228587  92145        1,968
# 2     3                   200325  91980          631
# 3     4                   187857  94957        1,063
# 4     5                   182750  94022       19,737

# %% [markdown]
# #### 1.5.1.1 df_median_income Wrangling Summary<a id='1.5.1.1_df_median_income_Wrangling_Summary'></a>
#
# #### For df_median_income DataFrame:
#    * Let's select only the columns we're interested on: "Median_Household_Income" & "Zip".
#    * Let's rename Median Household Income to "median_income_zipcode" & "Zip" to "zipcode"
#    * The Dataset we have is for 2010-2014 (latest ***Free*** Dataset), so according to https://fred.stlouisfed.org/series/MEHOINUSCAA646N Median income in CA has increased by Avg 5.3% between 2015-2019 so we'll adjust these numbers accordingly.

# %%
# let's check the data types in the df:
df_median_income.dtypes
# Out:
# Rank                        int64
# Median Household Income     int64
# Zip                        object
#  Population                object
# dtype: object

# %% [markdown]
# #### 1.5.1.2 Imputing NANs, Wrong Values and Duplicates<a id='1.5.1.2_Imputing_NANs_Wrong_Values_and_duplicates'></a>
#
# #### "Median Household Income" type is correct but the "Zip" is not correct, this need to be changed to int64:

# %%
# let's change "Zip" data type from 'object' to 'int':

df_median_income.iloc[:,2] = df_median_income.iloc[:,2].astype('int64')

# %%
# Confirm data types in df_median_income:
df_median_income.dtypes
# Out:
# Rank                        int64
# Median Household Income     int64
# Zip                         int64
#  Population                object
# dtype: object

# %% [markdown]
# #### "Zip" Column data type is corrected

# %%
# let's check if we have any NANs: 
df_median_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1686 entries, 0 to 1685
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Rank                     1686 non-null   int64
#  1   Median Household Income  1686 non-null   int64
#  2   Zip                      1686 non-null   int64
#  3    Population              1686 non-null   object
# dtypes: int64(3), object(1)
# memory usage: 52.8+ KB

# %% [markdown]
# #### No NANs in both of the needed columns: "Median_Household_Income" & "Zip"

# %%
# Now let's keep only "Median_Household_Income" & "Zip" in df_median_income:
df_median_income = df_median_income.iloc[:,[1,2]]

# %%
df_median_income.head()
# Out:
#    Median Household Income   Zip
# 0                   236912  94027
# 1                   228587  92145
# 2                   200325  91980
# 3                   187857  94957
# 4                   182750  94022

# %% [markdown]
# #### df_median_income has only 2 Columns: "Median_Household_Income" & "Zip"

# %%
# let's check if any duplicates:
duplicates = df_median_income.duplicated()
df_median_income[duplicates]
# Out:
# Empty DataFrame
# Columns: [Median Household Income, Zip ]
# Index: []

# %% [markdown]
# #### No Duplicates

# %%
# Now let's Give Column[0] & Column[1] a new lablel names:
df_median_income.rename(columns = {list(df_median_income)[0]: 'median_income_zipcode_2014', list(df_median_income)[1]: 'zipcode'}, inplace = True)
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %% [markdown]
# #### 1.5.1.3 Converting Dataset<a id='2.6.3.3_Converting_Dataset'></a>
#
# #### The Dataset we have is for 2010-2014 (latest Free Dataset), so according to https://fred.stlouisfed.org/series/MEHOINUSCAA646N Median income in CA has increased by Avg 5.3% between 2015-2019 so let's adjust these numbers accordingly:

# %%
# Increase Percentage: 1.053 = 100/100 + 5.3/100
df_median_income['median_income_zipcode_2019'] = df_median_income['median_income_zipcode_2014'] * 1.053
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_median_income.head()
# Out:
#    median_income_zipcode_2014  zipcode  median_income_zipcode_2019
# 0                      236912    94027                  249468.336
# 1                      228587    92145                  240702.111
# 2                      200325    91980                  210942.225
# 3                      187857    94957                  197813.421
# 4                      182750    94022                  192435.750

# %% [markdown]
# #### 1.5.1.4 Correcting Data Types<a id='2.6.3.4_Correcting_Data_Types'></a>

# %%
df_median_income.dtypes
# Out:
# median_income_zipcode_2014      int64
# zipcode                         int64
# median_income_zipcode_2019    float64
# dtype: object

# %%
# let's change median_income_zipcode_2019 float to int:
df_median_income.iloc[:,2] = df_median_income.iloc[:,2].astype('int64')
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
df_median_income.dtypes
# Out:
# median_income_zipcode_2014    int64
# zipcode                       int64
# median_income_zipcode_2019    int64
# dtype: object

# %% [markdown]
# #### 1.5.1.5 Drop Insignificant Columns<a id='1.5.1.5_Drop_Insignificant_Columns'></a>

# %%
# Now let's keep only "Median_Household_Income_2019" & "Zip" in df_median_income:
df_median_income = df_median_income.iloc[:,[1,2]]

# %%
df_median_income.head()
# Out:
#    zipcode  median_income_zipcode_2019
# 0    94027                      249468
# 1    92145                      240702
# 2    91980                      210942
# 3    94957                      197813
# 4    94022                      192435

# %% [markdown]
# #### 1.5.1.6 Visualization<a id='1.5.1.6_Visualization'></a>

# %%
# Let's visualize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df_median_income['median_income_zipcode_2019'], kde=True, bins=10)
ax.set_title('Median Income Distribution in California - 2019')
plt.grid(True)

# %% [markdown]
# #### 1.5.1.7 Saving Cleaned df<a id='1.5.1.7_Saving_Cleaned_df'></a>
#
# #### df_median_income is cleaned and now let's save it.

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_median_income, 'df_median_income.csv', datapath)

# %% [markdown]
# ### 1.5.2 df_malls wrangling<a id='1.5.2_df_malls_wrangling'></a>

# %%
df_malls.head()
# Out:
#        Mall/Shopping Center           City
# 0     Antelope Valley Mall       Palmdale
# 1               Arden Fair     Sacramento
# 2           Beverly Center    Los Angeles
# 3                Brea Mall           Brea
# 4   Del Amo Fashion Center       Torrance

# %% [markdown]
# ####  1.5.2.1 df_malls Wrangling Summary<a id='1.5.2.1_Wrangling_Summary'></a>
#
#
# #### df_malls DataFrame:
#    * For this dataFrame, we need to have malls count per city.
#    * let's make sure no NANs in both columns, no duplicates in the mall/Shopping Center column and correct datatype.
#    * let's change city to lowercase.
#    * let's rename "Mall/Shopping Center" to "malls_count_city" and "City" to "city".
#    * At the end, we need to have two columns "city" & "malls_count_city".

# %%
df_malls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186 entries, 0 to 185
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Mall/Shopping Center  186 non-null    object
#  1   City                  186 non-null    object
# dtypes: object(2)
# memory usage: 3.0+ KB

# %% [markdown]
# #### 1.5.2.2 Imputing NANs, Wrong Values and Duplicates<a id='1.5.2.2_Imputing_NANs_Wrong_Values_and_Duplicates)'></a>
#
# #### From above we can see that there's no NANs, and we have the correct datatype

# %%
# let's check if any duplicates:
duplicates = df_malls.duplicated()
df_malls[duplicates]
# Out:
# Empty DataFrame
# Columns: [Mall/Shopping Center, City]
# Index: []

# %% [markdown]
# #### 1.5.2.3 Renaming Columns<a id='1.5.2.3_Renaming_Columns'></a>

# %%
# Now let's Give Column[0] & Column[1] a new lablel names:
df_malls.rename(columns = {list(df_malls)[0]: 'malls', list(df_malls)[1]: 'city'}, inplace = True)

# %%
df_malls.head()
# Out:
#                       malls           city
# 0     Antelope Valley Mall       Palmdale
# 1               Arden Fair     Sacramento
# 2           Beverly Center    Los Angeles
# 3                Brea Mall           Brea
# 4   Del Amo Fashion Center       Torrance

# %%
# Let's groupby df_malls per city as below:
df_malls_n = df_malls.groupby('city').count()
df_malls_n = df_malls_n.reset_index()

# %%
df_malls_n.head()
# Out:
#         city  malls
# 0    Alameda      1
# 1    Anaheim      2
# 2   Anaheim       1
# 3    Antioch      1
# 4   Arcadia       1

# %%
# Now let's Give Column[0] & Column[1] a new lablel names:
df_malls_n.rename(columns = {list(df_malls_n)[1]: 'malls_count_city'}, inplace = True)

# %%
df_malls_n.head()
# Out:
#         city  malls_count_city
# 0    Alameda                 1
# 1    Anaheim                 2
# 2   Anaheim                  1
# 3    Antioch                 1
# 4   Arcadia                  1

# %% [markdown]
# #### 1.5.2.4 Visualization<a id='1.5.2.4_Visualization'></a>

# %%
# Let's visulize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df_malls_n['malls_count_city'], kde=True, bins=10)
ax.set_title('Malls Count Distribution in CA')
plt.grid(True)

# %%
#lowercase "city" columns, this will help us later when joining mutiple dfs:
df_malls_n['city'] = df_malls_n['city'].str.lower()

# %%
df_malls_n.head()
# Out:
#         city  malls_count_city
# 0    alameda                 1
# 1    anaheim                 2
# 2   anaheim                  1
# 3    antioch                 1
# 4   arcadia                  1

# %%
df_malls_final = df_malls_n

# %% [markdown]
# #### 1.5.2.5 Lowercase And Remove Spaces from Columns<a id='1.5.2.5_Lowercase_And_Remove_Spaces_from_Columns'></a>

# %%
df_malls_final['city'].unique()
# Out:
# array([' alameda', ' anaheim', ' anaheim ', ' antioch', ' arcadia ',
#        ' bakersfield ', ' beverly grove, los angeles', ' brea ',
#        ' buena park', ' burbank', ' cabazon', ' calabasas', ' calexico',
#        ' camarillo', ' campbell', ' canoga park ', ' capitola',
#        ' carlsbad', ' carlsbad ', ' carson', ' cerritos ', ' chico',
#        ' chula vista', ' citrus heights', ' commerce', ' concord',
#        ' concord ', ' corte madera', ' costa mesa ', ' culver city',
#        ' culver city ', ' daly city', ' danville', ' downey ',
#        ' eagle rock', ' eastvale', ' el cajon', ' el centro',
#        ' el cerrito', ' el segundo', ' emeryville', ' encino',
#        ' escondido ', ' eureka', ' fairfield ', ' folsom', ' fremont',
#        ' fresno', ' fresno ', ' gilroy', ' glendale', ' glendale ',
#        ' hanford', ' hayward', ' huntington beach', ' industry',
#        ' irvine', ' la jolla', ' la mesa', ' lakewood ', ' livermore',
# ...

# %% [markdown]
# #### Before saving the file let's remove the leading or the trailing space in the 'city' column:

# %%
df_malls_final['city'] = df_malls_final['city'].str.strip()

# %%
df_malls_final['city'].unique()
# Out:
# array(['alameda', 'anaheim', 'antioch', 'arcadia', 'bakersfield',
#        'beverly grove, los angeles', 'brea', 'buena park', 'burbank',
#        'cabazon', 'calabasas', 'calexico', 'camarillo', 'campbell',
#        'canoga park', 'capitola', 'carlsbad', 'carson', 'cerritos',
#        'chico', 'chula vista', 'citrus heights', 'commerce', 'concord',
#        'corte madera', 'costa mesa', 'culver city', 'daly city',
#        'danville', 'downey', 'eagle rock', 'eastvale', 'el cajon',
#        'el centro', 'el cerrito', 'el segundo', 'emeryville', 'encino',
#        'escondido', 'eureka', 'fairfield', 'folsom', 'fremont', 'fresno',
#        'gilroy', 'glendale', 'hanford', 'hayward', 'huntington beach',
#        'industry', 'irvine', 'la jolla', 'la mesa', 'lakewood',
#        'livermore', 'long beach', 'los angeles', 'malibu',
#        'manhattan beach', 'milpitas', 'mira mesa', 'mission viejo',
#        'modesto', 'montclair', 'montebello', 'monterey', 'moreno valley',
# ...

# %% [markdown]
# #### 1.5.2.6 Saving Cleaned df<a id='1.5.2.6_Saving_Cleaned_df'></a>
#
# #### df_malls_final is cleaned and now let's save it.

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_malls_final, 'df_malls_final.csv', datapath)

# %% [markdown]
# ### 1.5.3 df_universities wrangling<a id='1.5.3_df_universities_wrangling'></a>

# %%
df_universities.head()
# Out:
#                                               School           City  Enroll  \
# 0             Academy for Jewish Religion-California    Los Angeles      74
# 1                          Academy of Art University  San Francisco  18,535
# 2     Academy of Chinese Culture and Health Sciences        Oakland     149
# 3                             Academy of Couture Art  Beverly Hills      32
# 4  Acupuncture and Integrative Medicine College-B...       Berkeley     161
#
#   In-State Cost Out-State Cost
# 0             -              -
# 1   $38,806.00     $38,806.00
# 2             -              -
# 3   $24,738.00     $24,738.00
# 4             -              -

# %% [markdown]
# #### 1.5.3.1 df_universities Wrangling Summary<a id='1.5.3.1_df_universities_Wrangling_Summary'></a>
#
# #### df_universities DataFrame:
#    * For this dataFrame, we need to have universities count per city.
#    * let's make sure no NANs in both columns, no duplicates in the School column and correct datatype.
#    * let's change city to lowercase.
#    * let's rename "School" to "universities_count_city" and "City" to "city".
#    * At the end, we need to have two columns "city" & "universities_count_city".

# %% [markdown]
# #### 1.5.3.2 Imputing NANs, Wrong Values and Duplicates<a id='1.5.3.2_Imputing_NANs_Wrong_Values_and_Duplicates)'></a>

# %%
df_universities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   School          264 non-null    object
#  1   City            257 non-null    object
#  2   Enroll          264 non-null    object
#  3   In-State Cost   264 non-null    object
#  4   Out-State Cost  264 non-null    object
# dtypes: object(5)
# memory usage: 10.4+ KB

# %% [markdown]
# #### From above we can see that there's no NANs, and we have the correct datatype

# %%
# let's check if any duplicates:
duplicates = df_universities.duplicated()
df_universities[duplicates]
# Out:
# Empty DataFrame
# Columns: [School, City, Enroll, In-State Cost, Out-State Cost]
# Index: []

# %% [markdown]
# #### 1.5.3.3 Renaming Columns<a id='1.5.3.3_Renaming_Columns'></a>

# %%
# Now let's Give Column[0] & Column[1] a new lablel names:
df_universities.rename(columns = {list(df_universities)[0]: 'universities_count_city', list(df_universities)[1]: 'city'}, inplace = True)

# %%
df_universities.head()
# Out:
#                              universities_count_city           city  Enroll  \
# 0             Academy for Jewish Religion-California    Los Angeles      74
# 1                          Academy of Art University  San Francisco  18,535
# 2     Academy of Chinese Culture and Health Sciences        Oakland     149
# 3                             Academy of Couture Art  Beverly Hills      32
# 4  Acupuncture and Integrative Medicine College-B...       Berkeley     161
#
#   In-State Cost Out-State Cost
# 0             -              -
# 1   $38,806.00     $38,806.00
# 2             -              -
# 3   $24,738.00     $24,738.00
# 4             -              -

# %% [markdown]
# #### 1.5.3.4 Drop Insignificant Columns<a id='1.5.3.4_Drop_Insignificant_Columns'></a>

# %%
# Now let's keep "universities_count_city" and "city" in the df_universities:
df_universities = df_universities[['universities_count_city', 'city']]

# %%
df_universities.head()
# Out:
#                              universities_count_city           city
# 0             Academy for Jewish Religion-California    Los Angeles
# 1                          Academy of Art University  San Francisco
# 2     Academy of Chinese Culture and Health Sciences        Oakland
# 3                             Academy of Couture Art  Beverly Hills
# 4  Acupuncture and Integrative Medicine College-B...       Berkeley

# %% [markdown]
# #### 1.5.3.5 Group By On City<a id='1.5.3.5_Group_By_On_City'></a>

# %%
# Let's groupby df_universities per city as below:
df_universities_n = df_universities.groupby('city').count().reset_index()

# %%
df_universities_n.head()
# Out:
#           city  universities_count_city
# 0      Alameda                        1
# 1     Alhambra                        1
# 2  Aliso Viejo                        1
# 3      Anaheim                        7
# 4       Angwin                        1

# %% [markdown]
# #### 1.5.3.6 Lowercase City Column<a id='1.5.3.6_Lowercase_City_Column'></a>

# %%
#lowercase "city" columns, this will help us later when joining mutiple dfs:
df_universities_n['city'] = df_universities_n['city'].str.lower()

# %%
df_universities_n.head()
# Out:
#           city  universities_count_city
# 0      alameda                        1
# 1     alhambra                        1
# 2  aliso viejo                        1
# 3      anaheim                        7
# 4       angwin                        1

# %%
df_universities_n.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   city                     108 non-null    object
#  1   universities_count_city  108 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
df_universities_final = df_universities_n

# %% [markdown]
# #### 1.5.3.7 Visualization<a id='1.5.3.7_Visualization'></a>

# %%
# Let's visulize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df_universities_final['universities_count_city'], kde=True, bins=10)
ax.set_title('Universities Count Distribution in CA')
plt.grid(True)

# %%
df_universities_final['city'].unique()
# Out:
# array(['alameda', 'alhambra', 'aliso viejo', 'anaheim', 'angwin',
#        'arcata', 'atherton', 'azusa', 'bakersfield', 'belmont',
#        'berkeley', 'beverly hills', 'blue lake', 'burbank', 'camarillo',
#        'canyon country', 'carpinteria', 'carson', 'cerritos',
#        'chatsworth', 'chico', 'chula vista', 'claremont', 'clovis',
#        'costa mesa', 'culver city', 'cypress', 'davis', 'duarte',
#        'el cajon', 'emeryville', 'escondido', 'fair oaks', 'fremont',
#        'fresno', 'fullerton', 'glendora', 'hayward', 'hollywood',
#        'inglewood', 'irvine', 'la jolla', 'la mirada', 'la verne',
#        'laguna beach', 'laguna hills', 'lancaster', 'loma linda',
#        'long beach', 'los alamitos', 'los angeles', 'malibu', 'merced',
#        'monrovia', 'monterey', 'moraga', 'murrieta', 'newport beach',
#        'north hollywood', 'northridge', 'oakland', 'oceanside', 'ontario',
#        'orange', 'palo alto', 'pasadena', 'pleasant hill', 'pomona',
# ...

# %% [markdown]
# #### 1.5.3.8 Saving Cleaned df<a id='1.5.3.8_Saving_Cleaned_df'></a>
#
# #### df_universities_final is cleaned and now let's save it.

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_universities_final, 'df_universities_final.csv', datapath)

# %% [markdown]
# ### 1.5.4 df_greatschools wrangling<a id='1.5.4_df_greatschools_wrangling'></a>

# %%
df_greatschools.head()
# Out:
#    gsId                              name    type gradeRange  enrollment  \
# 0   NaN                          Bay Farm  public        K-8       610.0
# 1   NaN  Amelia Earhart Elementary School  public        K-5       651.0
# 2   NaN        Franklin Elementary School  public        K-5       335.0
# 3   NaN    Ruby Bridges Elementary School  public        K-5       484.0
# 4   NaN                   Maya Lin School  public        K-5       427.0
#
#    gsRating  parentRating     city state  districtId  \
# 0       9.0           5.0  Alameda    CA         1.0
# 1      10.0           5.0  Alameda    CA         1.0
# 2       8.0           5.0  Alameda    CA         1.0
# 3       3.0           5.0  Alameda    CA         1.0
# 4       6.0           5.0  Alameda    CA         1.0
#
#                           district  districtNCESId  \
# 0  Alameda Unified School District        601770.0
# 1  Alameda Unified School District        601770.0
# ...

# %% [markdown]
# #### 1.5.4.1 df_greatschools Wrangling Summary<a id='1.5.4.1_df_greatschools_Wrangling_Summary'></a>
#
# #### df_greatschools DataFrame:
#    * For this dataFrame, we need to keep below columns:
#      "name", "enrollment", "gsRating", "city", "ncesId", "lat" and "long"
#    * let's make sure no NANs , no duplicates and correct datatype in the above columns
#    * let's change city to lowercase.
#    * let's rename "name" to "school"
#    * At the end, we need to have 7 columns with  "school", "enrollment", "gsRating", "city", "ncesId", "lat" and "long"
#    * Using "ncesId" we'll be joining "df_greatschools" with "df_publichschools" ON zipcode.

# %%
df_greatschools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   gsId            0 non-null      float64
#  1   name            824 non-null    object
#  2   type            824 non-null    object
#  3   gradeRange      791 non-null    object
#  4   enrollment      776 non-null    float64
#  5   gsRating        708 non-null    float64
#  6   parentRating    738 non-null    float64
#  7   city            824 non-null    object
#  8   state           824 non-null    object
#  9   districtId      823 non-null    float64
#  10  district        823 non-null    object
#  11  districtNCESId  823 non-null    float64
#  12  address         824 non-null    object
#  13  phone           824 non-null    object
#  14  fax             770 non-null    object
#  15  website         675 non-null    object
#  16  ncesId          823 non-null    float64
# ...

# %% [markdown]
# #### 1.5.4.2 Drop Insignificant Columns<a id='1.5.4.2_Drop_Insignificant_Columns'></a>
#
# #### First let's keep the following columns: "name", "enrollment", "gsRating", "city", "ncesId", "lat" and "long"

# %%
# dropping insiginificant columns from df_greatschools:
df_greatschools = df_greatschools.iloc[:,[1,4,5,7,16,17,18]]

# %%
df_greatschools.head()
# Out:
#                                name  enrollment  gsRating     city  \
# 0                          Bay Farm       610.0       9.0  Alameda
# 1  Amelia Earhart Elementary School       651.0      10.0  Alameda
# 2        Franklin Elementary School       335.0       8.0  Alameda
# 3    Ruby Bridges Elementary School       484.0       3.0  Alameda
# 4                   Maya Lin School       427.0       6.0  Alameda
#
#          ncesId        lat        lon
# 0  6.017700e+10  37.739000 -122.25195
# 1  6.017700e+10  37.745290 -122.23928
# 2  6.017700e+10  37.769035 -122.26160
# 3  6.017701e+10  37.781834 -122.28614
# 4  6.017701e+10  37.772724 -122.27189

# %% [markdown]
# #### 1.5.4.3 Renaming Columns<a id='1.5.4.3_Renaming_Columns'></a>
#
# #### let's rename "name" to "school"

# %%
# Now let's Give Column[0] a new lablel names:
df_greatschools.rename(columns = {list(df_greatschools)[0]: 'school'}, inplace = True)
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_greatschools.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm       610.0       9.0  Alameda
# 1  Amelia Earhart Elementary School       651.0      10.0  Alameda
# 2        Franklin Elementary School       335.0       8.0  Alameda
# 3    Ruby Bridges Elementary School       484.0       3.0  Alameda
# 4                   Maya Lin School       427.0       6.0  Alameda
#
#          ncesId        lat        lon
# 0  6.017700e+10  37.739000 -122.25195
# 1  6.017700e+10  37.745290 -122.23928
# 2  6.017700e+10  37.769035 -122.26160
# 3  6.017701e+10  37.781834 -122.28614
# 4  6.017701e+10  37.772724 -122.27189

# %%
df_greatschools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      824 non-null    object
#  1   enrollment  776 non-null    float64
#  2   gsRating    708 non-null    float64
#  3   city        824 non-null    object
#  4   ncesId      823 non-null    float64
#  5   lat         824 non-null    float64
#  6   lon         824 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 45.2+ KB

# %% [markdown]
# #### 1.5.4.4 Imputing NANs, Wrong Values and Duplicates<a id='1.5.4.4_Imputing_NANs_Wrong_Values_and_Duplicates'></a>
#
# #### From above we can see that we have NANs at "enrollment",  "gsRating" and "ncesId" ... so let's investigate further:
#    1. One missing value at "ncesId" so this needs to be dropped
#    2. Missing Values at "gsRating" to imputing them with statistical measures such as mean "gsRating".
#    3. Missing Values at "enrollment" to imputing them with statistical measures such as median "enrollment".

# %%
#Let's investigate the NANs in our Dataframe:
missing = pd.concat([df_greatschools.isnull().sum(), 100 * df_greatschools.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#             count          %
# gsRating      116  14.077670
# enrollment     48   5.825243
# ncesId          1   0.121359
# school          0   0.000000
# city            0   0.000000
# lat             0   0.000000
# lon             0   0.000000

# %% [markdown]
# #### 14% NANs at "gsRating" to be imputed with  mean "gsRating"
# #### ~6% NANs at "enrollment" to be imputed with  median of "enrollment"
# #### 0.1% NANs at "ncesId" to be dropped.

# %%
# let's first start with "gsrating", let's impute the missing values with the mean:
gsRating_mean = df_greatschools['gsRating'].mean()
gsRating_imputed = df_greatschools.fillna({'gsRating': gsRating_mean})
gsRating_imputed.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm       610.0       9.0  Alameda
# 1  Amelia Earhart Elementary School       651.0      10.0  Alameda
# 2        Franklin Elementary School       335.0       8.0  Alameda
# 3    Ruby Bridges Elementary School       484.0       3.0  Alameda
# 4                   Maya Lin School       427.0       6.0  Alameda
#
#          ncesId        lat        lon
# 0  6.017700e+10  37.739000 -122.25195
# 1  6.017700e+10  37.745290 -122.23928
# 2  6.017700e+10  37.769035 -122.26160
# 3  6.017701e+10  37.781834 -122.28614
# 4  6.017701e+10  37.772724 -122.27189

# %%
# let's repeat the previous step with "enrollment", but this time let's impute the missing values with the median:
gsRating_median = gsRating_imputed['enrollment'].median()
gsRating_imputed_m = gsRating_imputed.fillna({'enrollment': gsRating_median})
gsRating_imputed_m.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm       610.0       9.0  Alameda
# 1  Amelia Earhart Elementary School       651.0      10.0  Alameda
# 2        Franklin Elementary School       335.0       8.0  Alameda
# 3    Ruby Bridges Elementary School       484.0       3.0  Alameda
# 4                   Maya Lin School       427.0       6.0  Alameda
#
#          ncesId        lat        lon
# 0  6.017700e+10  37.739000 -122.25195
# 1  6.017700e+10  37.745290 -122.23928
# 2  6.017700e+10  37.769035 -122.26160
# 3  6.017701e+10  37.781834 -122.28614
# 4  6.017701e+10  37.772724 -122.27189

# %%
# let's drop missing values at "ncesId":

gsRating_imputed_m_dropped = gsRating_imputed_m.dropna(subset = ['ncesId'])
gsRating_imputed_m_dropped.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm       610.0       9.0  Alameda
# 1  Amelia Earhart Elementary School       651.0      10.0  Alameda
# 2        Franklin Elementary School       335.0       8.0  Alameda
# 3    Ruby Bridges Elementary School       484.0       3.0  Alameda
# 4                   Maya Lin School       427.0       6.0  Alameda
#
#          ncesId        lat        lon
# 0  6.017700e+10  37.739000 -122.25195
# 1  6.017700e+10  37.745290 -122.23928
# 2  6.017700e+10  37.769035 -122.26160
# 3  6.017701e+10  37.781834 -122.28614
# 4  6.017701e+10  37.772724 -122.27189

# %%
gsRating_imputed_m_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 823 entries, 0 to 823
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      823 non-null    object
#  1   enrollment  823 non-null    float64
#  2   gsRating    823 non-null    float64
#  3   city        823 non-null    object
#  4   ncesId      823 non-null    float64
#  5   lat         823 non-null    float64
#  6   lon         823 non-null    float64
# dtypes: float64(5), object(2)
# memory usage: 51.4+ KB

# %% [markdown]
# #### As we can see above no more missing values @ gsRating_imputed_m_dropped

# %%
# let's rename the df:
df_gsRating_v1 = gsRating_imputed_m_dropped

# %% [markdown]
# #### 1.5.4.5 Correcting Data Types<a id='1.5.4.5_Correcting_Data_Types'></a>
#
# #### let's change datatypes as below:
#   1. "enrollment" datatype from 'float64' to 'int64'
#   2. "gsRating" datatype from 'float64' to 'int64'
#   3. "ncesId" datatype from 'float64' to 'int64'

# %%
# let's start with "enrollment" datatype from 'float64' to 'int64':
df_gsRating_v1.loc[:,'enrollment'] = df_gsRating_v1['enrollment'].astype('int64')
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\indexing.py:1743: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
# Next "gsRating" datatype from 'float64' to 'int64':
df_gsRating_v1.loc[:,'gsRating'] = df_gsRating_v1['gsRating'].astype('int64')

# %%
# Finally "ncesId" datatype from 'float64' to 'int64':
df_gsRating_v1.loc[:,'ncesId'] = df_gsRating_v1['ncesId'].astype('int64')

# %%
df_gsRating_v1.dtypes
# Out:
# school         object
# enrollment      int64
# gsRating        int64
# city           object
# ncesId          int64
# lat           float64
# lon           float64
# dtype: object

# %%
df_gsRating_v1.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm         610         9  Alameda
# 1  Amelia Earhart Elementary School         651        10  Alameda
# 2        Franklin Elementary School         335         8  Alameda
# 3    Ruby Bridges Elementary School         484         3  Alameda
# 4                   Maya Lin School         427         6  Alameda
#
#         ncesId        lat        lon
# 0  60177000006  37.739000 -122.25195
# 1  60177000043  37.745290 -122.23928
# 2  60177004337  37.769035 -122.26160
# 3  60177011549  37.781834 -122.28614
# 4  60177013107  37.772724 -122.27189

# %% [markdown]
# #### 1.5.4.6 Lowercase City Column<a id='1.5.4.6_Lowercase_City_Column'></a>

# %%
# finally let's lowercase "city" column:
df_gsRating_v1['city'] = df_gsRating_v1['city'].str.lower()
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_gsRating_v1.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm         610         9  alameda
# 1  Amelia Earhart Elementary School         651        10  alameda
# 2        Franklin Elementary School         335         8  alameda
# 3    Ruby Bridges Elementary School         484         3  alameda
# 4                   Maya Lin School         427         6  alameda
#
#         ncesId        lat        lon
# 0  60177000006  37.739000 -122.25195
# 1  60177000043  37.745290 -122.23928
# 2  60177004337  37.769035 -122.26160
# 3  60177011549  37.781834 -122.28614
# 4  60177013107  37.772724 -122.27189

# %%
#rename the df:

df_gsRating_final = df_gsRating_v1

# %% [markdown]
# #### 1.5.4.7 Visualization<a id='1.5.4.7_Visualization'></a>

# %%
# Let's visualize the dataframe using a histogram:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df_gsRating_final['gsRating'], kde=True, bins=10)
ax.set_title('Schools Rating in North California')
plt.grid(True)

# %%
# Let's visualize the dataframe using a joint plot to do some automatic kernel density estimation and regression:
sns.jointplot('gsRating', 'enrollment', data=df_gsRating_final, kind='reg', height=8, ratio=3, marginal_ticks=True);
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### 1.5.4.8 Saving Cleaned df<a id='1.5.4.8_Saving_Cleaned_df'></a>
#
# #### df_gsRating_final is cleaned and now let's save it.

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_gsRating_final, 'df_gsRating_final.csv', datapath)

# %% [markdown]
# ### 1.5.5 df_bart wrangling<a id='1.5.5 df_bart_wrangling'></a>

# %%
df_bart.head()
# Out:
#                            BART Station        City  zip_code parking
# 0  12th St. Oakland City Center Station     Oakland     94612      No
# 1              19th St. Oakland Station     Oakland     94612      No
# 2                       Antioch Station     Antioch     94509     Yes
# 3      Berryessa/North San José Station    San jose     95133     Yes
# 4           Dublin / Pleasanton Station  Pleasanton     94588     Yes

# %%
df_bart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BART Station  33 non-null     object
#  1   City          33 non-null     object
#  2   zip_code      33 non-null     int64
#  3   parking       33 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB

# %% [markdown]
# #### 1.5.5.1 df_bart Wrangling Summary<a id='1.5.5.1_df_bart_Wrangling_Summary'></a>
#
# #### df_bart DataFrame:
#    * For this dataFrame, we need to keep two columns: 'zipcode' & 'bart_count_zipcode'
#      "name", "enrollment", "gsRating", "city", "ncesId", "lat" and "long"
#    * let's make sure no NANs , no duplicates and correct datatype in the above columns
#    * let's rename "zip_code" to "zipcode"

# %% [markdown]
# #### 1.5.5.2 Imputing NANs, Wrong Values and Duplicates<a id='1.5.5.2_Imputing_NANs_Wrong_Values_and_Duplicates)'></a>

# %%
df_bart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BART Station  33 non-null     object
#  1   City          33 non-null     object
#  2   zip_code      33 non-null     int64
#  3   parking       33 non-null     object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB

# %% [markdown]
# #### As we can see above, there's no NANs, and all columns have correct datatype

# %% [markdown]
# #### 1.5.5.3 Group By On Zipcode<a id='1.5.5.3_Group_By_On_Zipcode'></a>

# %%
# let's groupby the datafram to get to columns zipcode and parking count as below:
df_bart_new = df_bart.groupby('zip_code')['parking'].count().reset_index()

# %%
df_bart_new
# Out:
#     zip_code  parking
# 0      94509        1
# 1      94520        2
# 2      94530        2
# 3      94541        1
# 4      94544        1
# 5      94546        1
# 6      94549        1
# 7      94563        1
# 8      94565        2
# 9      94568        1
# 10     94577        1
# 11     94578        1
# 12     94587        1
# 13     94588        1
# 14     94596        1
# 15     94597        1
# 16     94601        1
# 17     94607        2
# 18     94609        1
# 19     94612        2
# 20     94618        1
# 21     94621        2
# 22     94702        1
# 23     94703        1
# 24     94704        1
# 25     94801        1
# 26     95133        1

# %%
df_bart_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zip_code  27 non-null     int64
#  1   parking   27 non-null     int64
# dtypes: int64(2)
# memory usage: 560.0 bytes

# %% [markdown]
# #### both of the columns have correct datatype

# %% [markdown]
# #### 1.5.5.4 Renaming Columns<a id='1.5.5.4_Renaming_Columns'></a>

# %%
# Now let's Give Column[0] &  Column[1]a new lablel names:
df_bart_new.rename(columns = {list(df_bart_new)[0]: 'zipcode', list(df_bart_new)[1]: 'bart_count_zipcode'}, inplace = True)

# %%
df_bart_new.head()
# Out:
#    zipcode  bart_count_zipcode
# 0    94509                   1
# 1    94520                   2
# 2    94530                   2
# 3    94541                   1
# 4    94544                   1

# %%
df_bart_final = df_bart_new

# %% [markdown]
# #### 1.5.5.5 Saving Cleaned df<a id='1.5.5.5_Saving_Cleaned_df'></a>
#
# #### df_bart_final is cleaned and now let's save it.

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_bart_final, 'df_bart_final.csv', datapath)

# %% [markdown]
# ### 1.5.6 df_publichschools wrangling<a id='1.5.6_df_publichschools_wrangling'></a>

# %%
df_publichschools.head()
# Out:
#           ï»¿X            Y  OBJECTID        NCESID  \
# 0 -13510876.88  4665941.578        10  6.014321e+10
# 1 -13322124.52  4156228.095        11  6.014361e+10
# 2 -13612750.75  4547977.423        12  6.017701e+10
# 3 -13408470.44  4153714.967        13  6.055801e+10
# 4 -13174788.11  4052775.246        14  6.064501e+10
#
#                                                 NAME               ADDRESS  \
# 0                       PARAMOUNT COLLEGIATE ACADEMY   4010 EL CAMINO AVE.
# 1                                OLIVE GROVE CHARTER      4500 HIGHWAY 166
# 2                  THE ACADEMY OF ALAMEDA ELEMENTARY      401 PACIFIC AVE.
# 3  JIM?NEZ ROBERTO AND DR. FRANCISCO ELEMENTARY S...  1970 S. BISCAYNE ST.
# 4  BURBANK UNIFIED INDEPENDENT LEARNING ACADEMY (...       3715 ALLAN AVE.
#
#           CITY STATE    ZIP           ZIP4  ...     VAL_METHOD  \
# 0   SACRAMENTO    CA  95821           6602  ...  IMAGERY/OTHER
# 1   NEW CUYAMA    CA  93254           9720  ...  IMAGERY/OTHER
# ...

# %% [markdown]
# ####  1.5.6.1 df_publichschools Wrangling Summary<a id='1.5.6.1_df_publichschools_Wrangling_Summary'></a>
#
# #### df_publichschools DataFrame:
#    * For this dataFrame, we need to keep two columns: 'ZIP' & 'NCESID'
#    * let's make sure no NANs , no duplicates and correct datatype in the above columns
#    * let's rename "ZIP" to "zipcode" & "NCESID" to "ncesId"
#    * this df is needed so we can add zipcode the df_gsRating_final.

# %% [markdown]
# #### 1.5.6.2 Drop Insignificant Columns<a id='1.5.6.2_Drop_Insignificant_Columns'></a>

# %%
#let's trim the df to keep only the desired columns 'ZIP' & 'NCESID':
df_publichschools = df_publichschools.iloc[:,[3,8]]

# %%
df_publichschools.head()
# Out:
#          NCESID    ZIP
# 0  6.014321e+10  95821
# 1  6.014361e+10  93254
# 2  6.017701e+10  94501
# 3  6.055801e+10  93458
# 4  6.064501e+10  91505

# %%
df_publichschools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10442 entries, 0 to 10441
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NCESID  10442 non-null  float64
#  1   ZIP     10442 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 163.3 KB

# %% [markdown]
# #### 1.5.6.3 Correcting Data Types<a id='1.5.6.3_Correcting_Data_Types'></a>

# %% [markdown]
# #### As shown above, there's no NANs but "NCESID" datatype needs to changed from "float64" to "int64"

# %%
#let's change "NCESID" datatype from "float64" to "int64":
df_publichschools['NCESID'] = df_publichschools['NCESID'].astype('int64')
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_publichschools.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10442 entries, 0 to 10441
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NCESID  10442 non-null  int64
#  1   ZIP     10442 non-null  int64
# dtypes: int64(2)
# memory usage: 163.3 KB

# %%
df_publichschools.head()
# Out:
#         NCESID    ZIP
# 0  60143213940  95821
# 1  60143613948  93254
# 2  60177013871  94501
# 3  60558013869  93458
# 4  60645013886  91505

# %% [markdown]
# #### 1.5.6.4 Renaming Columns<a id='1.5.6.4_Renaming_Columns'></a>
#
# #### data types are fixed now, so let's rename both of these columns:

# %%
# let's rename "ZIP" to "zipcode" & "NCESID" to "ncesId":
df_publichschools.rename(columns = {list(df_publichschools)[0]: 'ncesId', list(df_publichschools)[1]: 'zipcode'}, inplace = True)
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_publichschools.head()
# Out:
#         ncesId  zipcode
# 0  60143213940    95821
# 1  60143613948    93254
# 2  60177013871    94501
# 3  60558013869    93458
# 4  60645013886    91505

# %% [markdown]
# #### 1.5.6.5 Merge df_greatschools & df_publichschools ON ncesId<a id='1.5.6.5_Merge df_greatschools_&_df_publichschools_ON_ncesId'></a>
#
# #### df_publichschools is cleaned and structure with "zipcode" & "ncesId" so let's use this df to add a zipcode to df_gsRating_final by merging df_gsRating_final & df_publichschools ON ncesId:

# %%
gsRating_final_df = pd.merge(df_gsRating_final, df_publichschools, on='ncesId')

# %%
gsRating_final_df.head()
# Out:
#                              school  enrollment  gsRating     city  \
# 0                          Bay Farm         610         9  alameda
# 1  Amelia Earhart Elementary School         651        10  alameda
# 2        Franklin Elementary School         335         8  alameda
# 3    Ruby Bridges Elementary School         484         3  alameda
# 4                   Maya Lin School         427         6  alameda
#
#         ncesId        lat        lon  zipcode
# 0  60177000006  37.739000 -122.25195    94502
# 1  60177000043  37.745290 -122.23928    94502
# 2  60177004337  37.769035 -122.26160    94501
# 3  60177011549  37.781834 -122.28614    94501
# 4  60177013107  37.772724 -122.27189    94501

# %%
gsRating_final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 790 entries, 0 to 789
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      790 non-null    object
#  1   enrollment  790 non-null    int64
#  2   gsRating    790 non-null    int64
#  3   city        790 non-null    object
#  4   ncesId      790 non-null    int64
#  5   lat         790 non-null    float64
#  6   lon         790 non-null    float64
#  7   zipcode     790 non-null    int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 55.5+ KB

# %% [markdown]
# #### Merge Output has no NANs and all datatypes are correct.
#
# #### 1.5.6.6 Group By to get a new df with zipcode & gsRating<a id='1.5.6.6_Group_By_to_get_a_new_df_with_zipcode_&_gsRating'></a>
#
# now let's build 2 data frames one gives avg school rate per zipcode and the second will give schools count per zipcode

# %%
avg_gsRating_zipcode = gsRating_final_df[['zipcode','gsRating']].groupby('zipcode').mean().reset_index()

# %%
avg_gsRating_zipcode.head(20)
# Out:
#     zipcode  gsRating
# 0     93440  4.000000
# 1     94022  8.166667
# 2     94024  9.200000
# 3     94025  5.333333
# 4     94028  7.000000
# 5     94040  7.500000
# 6     94041  8.000000
# 7     94043  6.333333
# 8     94085  3.666667
# 9     94086  5.750000
# 10    94087  7.363636
# 11    94089  5.000000
# 12    94301  8.333333
# 13    94303  3.894737
# 14    94304  5.000000
# 15    94305  7.500000
# 16    94306  8.250000
# 17    94501  6.642857
# 18    94502  9.500000
# 19    94503  5.000000

# %%
avg_gsRating_zipcode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zipcode   118 non-null    int64
#  1   gsRating  118 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.0 KB

# %% [markdown]
# ####  1.5.6.7 Round gsRating<a id='1.5.6.7_Round_gsRating'></a>

# %%
#let's round gsratings
avg_gsRating_zipcode_final = avg_gsRating_zipcode.round({"gsRating":0})

# %%
avg_gsRating_zipcode_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zipcode   118 non-null    int64
#  1   gsRating  118 non-null    float64
# dtypes: float64(1), int64(1)
# memory usage: 2.0 KB

# %%
avg_gsRating_zipcode_final.head()
# Out:
#    zipcode  gsRating
# 0    93440       4.0
# 1    94022       8.0
# 2    94024       9.0
# 3    94025       5.0
# 4    94028       7.0

# %% [markdown]
# ####  1.5.6.8 Correcting Data Types in avg_gsRating_zipcode_final<a id='1.5.6.8_Correcting_Data_Types_in_avg_gsRating_zipcode_final'></a>

# %%
avg_gsRating_zipcode_final['gsRating'] = avg_gsRating_zipcode_final['gsRating'].astype('int64')

# %%
avg_gsRating_zipcode_final.dtypes
# Out:
# zipcode     int64
# gsRating    int64
# dtype: object

# %% [markdown]
# #### 1.5.6.9 Renaming Columns in avg_gsRating_zipcode_final<a id='1.5.6.9_Renaming_Columns_in_avg_gsRating_zipcode_final'></a>
#
# #### Now let's rename "gsRating" to "Avg_greatschool_rating_zipcode"

# %%
# Now let's Give Column[1]a new lablel name:
avg_gsRating_zipcode_final.rename(columns = {list(avg_gsRating_zipcode_final)[1]: 'Avg_greatschool_rating_zipcode'}, inplace = True)

# %%
avg_gsRating_zipcode_final.head()
# Out:
#    zipcode  Avg_greatschool_rating_zipcode
# 0    93440                               4
# 1    94022                               8
# 2    94024                               9
# 3    94025                               5
# 4    94028                               7

# %% [markdown]
# #### 1.5.6.10 Group By to get a new df with zipcode & school_count<a id='1.5.6.10_Group_By_to_get_a_new_df_with_zipcode_&_gsRating'></a>
#
# #### Now let's create a new df with schoo count per zipcode:

# %%
School_count_zipcode = gsRating_final_df[['zipcode','gsRating']].groupby('zipcode').count().reset_index()

# %%
School_count_zipcode.head()
# Out:
#    zipcode  gsRating
# 0    93440         1
# 1    94022         6
# 2    94024         5
# 3    94025         6
# 4    94028         2

# %%
School_count_zipcode.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   zipcode   118 non-null    int64
#  1   gsRating  118 non-null    int64
# dtypes: int64(2)
# memory usage: 2.0 KB

# %% [markdown]
# #### 1.5.6.11 Renaming Columns in School_count_zipcode<a id='1.5.6.11_Renaming_Columns_in_School_count_zipcode'></a>
#
# #### Now let's rename "gsRating" to "school_count_zipcode"

# %%
# Now let's Give Column[1]a new lablel name:
School_count_zipcode.rename(columns = {list(School_count_zipcode)[1]: 'school_count_zipcode'}, inplace = True)

# %%
School_count_zipcode.head()
# Out:
#    zipcode  school_count_zipcode
# 0    93440                     1
# 1    94022                     6
# 2    94024                     5
# 3    94025                     6
# 4    94028                     2

# %% [markdown]
# ####  1.5.6.12 Merge avg_gsRating_zipcode_final & School_count_zipcode on Zipcode<a id='1.5.6.12_Merge avg_gsRating_zipcode_final_&_School_count_zipcode_on_Zipcode'></a>
#
# #### Now let's merge avg_gsRating_zipcode_final & School_count_zipcode on zipcode

# %%
school_df = pd.merge(avg_gsRating_zipcode_final, School_count_zipcode, on='zipcode')

# %%
school_df.head()
# Out:
#    zipcode  Avg_greatschool_rating_zipcode  school_count_zipcode
# 0    93440                               4                     1
# 1    94022                               8                     6
# 2    94024                               9                     5
# 3    94025                               5                     6
# 4    94028                               7                     2

# %%
school_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 118 entries, 0 to 117
# Data columns (total 3 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   zipcode                         118 non-null    int64
#  1   Avg_greatschool_rating_zipcode  118 non-null    int64
#  2   school_count_zipcode            118 non-null    int64
# dtypes: int64(3)
# memory usage: 3.7 KB

# %% [markdown]
# #### Summary:
#   1. Two dfs were merged "df_gsRating_final" & "df_publichschools" ON "ncesId"
#   2. As result of the merge we produced 2 dfs "avg_gsRating_zipcode_final" & "School_count_zipcode".
#   3. Again we merged "avg_gsRating_zipcode_final" & "School_count_zipcode" on "zipcode" and produced "school_df" as a final df!
#
#
# #### 1.5.6.13 Saving Cleaned df<a id='1.5.6.13_Saving_Cleaned_df'></a>

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(school_df, 'school_df.csv', datapath)

# %% [markdown]
#   ### 1.5.7 df_hotness wrangling<a id='1.5.7_df_hotness_wrangling'></a>

# %%
df_hotness.head()
# Out:
#    month_date_yyyymm  postal_code         zip_name  nielsen_hh_rank  \
# 0             202011        94607      oakland, ca             3432
# 1             202011        94087    sunnyvale, ca              480
# 2             202011        94520      concord, ca             2603
# 3             202011        95054  santa clara, ca             4894
# 4             202011        94706       albany, ca             5769
#
#    hotness_rank  hotness_rank_mm  hotness_rank_yy  hotness_score  \
# 0          9029           -703.0          -4708.0      31.017005
# 1          5887            854.0          -1431.0      51.847613
# 2           170            114.0            149.0      95.801995
# 3          7732            854.0          -4219.0      40.295945
# 4          6382           -411.0          -4649.0      49.076194
#
#    supply_score  demand_score  ...  median_days_on_market_yy  \
# 0     57.292348      4.741661  ...                    0.3750
# ...

# %%
df_hotness.columns.unique()
# Out:
# Index(['month_date_yyyymm', 'postal_code', 'zip_name', 'nielsen_hh_rank',
#        'hotness_rank', 'hotness_rank_mm', 'hotness_rank_yy', 'hotness_score',
#        'supply_score', 'demand_score', 'median_days_on_market',
#        'median_days_on_market_mm', 'median_dom_mm_day',
#        'median_days_on_market_yy', 'median_dom_yy_day', 'median_dom_vs_us',
#        'ldpviews_per_property_mm', 'ldpviews_per_property_yy',
#        'ldpviews_per_property_vs_us', 'median_listing_price',
#        'median_listing_price_mm', 'median_listing_price_yy',
#        'median_listing_price_vs_us'],
#       dtype='object')

# %%
df_hotness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   month_date_yyyymm            3732 non-null   int64
#  1   postal_code                  3732 non-null   int64
#  2   zip_name                     3732 non-null   object
#  3   nielsen_hh_rank              3732 non-null   int64
#  4   hotness_rank                 3732 non-null   int64
#  5   hotness_rank_mm              2765 non-null   float64
#  6   hotness_rank_yy              2660 non-null   float64
#  7   hotness_score                3732 non-null   float64
#  8   supply_score                 3732 non-null   float64
#  9   demand_score                 3732 non-null   float64
#  10  median_days_on_market        3732 non-null   float64
#  11  median_days_on_market_mm     2906 non-null   float64
#  12  median_dom_mm_day            2906 non-null   float64
# ...

# %% [markdown]
# ####  1.5.7.1 df_publichschools Wrangling Summary<a id='1.5.7.1_df_publichschools_Wrangling_Summary'></a>
#
# #### df_hotness DataFrame:
#    * For this dataFrame, we need to keep below columns:
#    'month_date_yyyymm', 'postal_code', 'hotness_score','supply_score', 'demand_score', 'median_days_on_market', 'median_listing_price'
#    * let's make sure no NANs , no duplicates and correct datatype in the above columns
#    * let's rename 'postal_code'
#    * Lets 'month_date_yyyymm' >= 201912

# %% [markdown]
# ####  1.5.7.2 Drop Insignificant Columns<a id='1.5.7.2_Drop_Insignificant_Columns'></a>

# %%
#let's first trim df_hotness to have the desired columns:
df_hotness = df_hotness.iloc[:,[0,1,7,8,9,10,19]]

# %%
df_hotness.head()
# Out:
#    month_date_yyyymm  postal_code  hotness_score  supply_score  demand_score  \
# 0             202011        94607      31.017005     57.292348      4.741661
# 1             202011        94087      51.847613     93.320798     10.374428
# 2             202011        94520      95.801995     97.179529     94.424460
# 3             202011        95054      40.295945     69.514388     11.077502
# 4             202011        94706      49.076194     78.654349     19.498038
#
#    median_days_on_market  median_listing_price
# 0                   49.5              692050.0
# 1                   30.5             1895049.5
# 2                   25.5              568050.0
# 3                   44.0              743994.0
# 4                   39.5              549550.0

# %% [markdown]
# #### so now we have only 7 columns.
#
# #### 1.5.7.3 Filter df_hotness to have only latest 12 Months<a id='1.5.7.3_Filter_df_hotness_to_have_only_latest_12_Months'></a>

# %%
df_hotness.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3732 entries, 0 to 3731
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   month_date_yyyymm      3732 non-null   int64
#  1   postal_code            3732 non-null   int64
#  2   hotness_score          3732 non-null   float64
#  3   supply_score           3732 non-null   float64
#  4   demand_score           3732 non-null   float64
#  5   median_days_on_market  3732 non-null   float64
#  6   median_listing_price   3732 non-null   float64
# dtypes: float64(5), int64(2)
# memory usage: 204.2 KB

# %%
df_hotness = df_hotness[df_hotness['month_date_yyyymm'] >= 201912]

# %%
df_hotness.head()
# Out:
#    month_date_yyyymm  postal_code  hotness_score  supply_score  demand_score  \
# 0             202011        94607      31.017005     57.292348      4.741661
# 1             202011        94087      51.847613     93.320798     10.374428
# 2             202011        94520      95.801995     97.179529     94.424460
# 3             202011        95054      40.295945     69.514388     11.077502
# 4             202011        94706      49.076194     78.654349     19.498038
#
#    median_days_on_market  median_listing_price
# 0                   49.5              692050.0
# 1                   30.5             1895049.5
# 2                   25.5              568050.0
# 3                   44.0              743994.0
# 4                   39.5              549550.0

# %%
df_hotness.tail()
# Out:
#      month_date_yyyymm  postal_code  hotness_score  supply_score  \
# 834             201912        94025      61.981475     63.863712
# 835             201912        94583      91.171022     86.377770
# 836             201912        94596      80.430036     70.234866
# 837             201912        94022      56.007278     50.036388
# 838             201912        94565      92.077407     96.963282
#
#      demand_score  median_days_on_market  median_listing_price
# 834     60.099239                   70.0             2975050.0
# 835     95.964274                   54.0              852450.0
# 836     90.625207                   65.5              880000.0
# 837     61.978167                   79.5             4143050.0
# 838     87.191532                   40.0              462500.0

# %% [markdown]
# #### df_hotness now is having only a one year of data to match the main "df_main_sold_houses"
# There're no NANs !!!
#
#
# #### 1.5.7.4 Group by on zipcode to have avg_score_per_year<a id='1.5.7.4_Group_by-on_zipcode_to_have_avg_score_per_year'></a>

# %%
# lt's group by 'postal_code', 'hotness_score','supply_score','demand_score' on 'postal_code' by taking the mean:
avg_score_per_year = df_hotness[['postal_code', 'hotness_score','supply_score','demand_score']].groupby('postal_code').mean().reset_index()

# %%
avg_score_per_year.head()
# Out:
#    postal_code  hotness_score  supply_score  demand_score
# 0        94022      50.606720     69.256115     31.957325
# 1        94025      55.295253     80.526624     30.063883
# 2        94028      41.714797     56.533650     26.895945
# 3        94040      50.479553     89.297743     11.661363
# 4        94043      53.297355     91.161242     15.433468

# %%
avg_score_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postal_code    82 non-null     int64
#  1   hotness_score  82 non-null     float64
#  2   supply_score   82 non-null     float64
#  3   demand_score   82 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 2.7 KB

# %% [markdown]
# #### There's no NANs
#
#
# #### 1.5.7.5 Round Columns<a id='1.5.7.5_Round_Columns'></a>

# %%
#let's round avg_score_per_year:
avg_score_per_year = avg_score_per_year.round({"hotness_score":2,"supply_score":2,"demand_score":2})

# %%
avg_score_per_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 82 entries, 0 to 81
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   postal_code    82 non-null     int64
#  1   hotness_score  82 non-null     float64
#  2   supply_score   82 non-null     float64
#  3   demand_score   82 non-null     float64
# dtypes: float64(3), int64(1)
# memory usage: 2.7 KB

# %%
avg_score_per_year.head()
# Out:
#    postal_code  hotness_score  supply_score  demand_score
# 0        94022          50.61         69.26         31.96
# 1        94025          55.30         80.53         30.06
# 2        94028          41.71         56.53         26.90
# 3        94040          50.48         89.30         11.66
# 4        94043          53.30         91.16         15.43

# %% [markdown]
# ####  1.5.7.6 Renaming Columns in avg_score_per_year<a id='1.5.7.6_Renaming_Columns_in_avg_score_per_year'></a>

# %%
# Now let's Give Column[0] a new lablel name:
avg_score_per_year.rename(columns = {list(avg_score_per_year)[0]: 'zipcode'}, inplace = True)

# %%
avg_score_per_year.head()
# Out:
#    zipcode  hotness_score  supply_score  demand_score
# 0    94022          50.61         69.26         31.96
# 1    94025          55.30         80.53         30.06
# 2    94028          41.71         56.53         26.90
# 3    94040          50.48         89.30         11.66
# 4    94043          53.30         91.16         15.43

# %% [markdown]
# ####  1.5.7.7 Saving Cleaned df<a id='1.5.7.7_Saving_Cleaned_df'></a>
#
# #### Finally, let's save   "housing_final_df"

# %%
housing_final_df_v1 = avg_score_per_year

# %%
housing_final_df_v1.head()
# Out:
#    zipcode  hotness_score  supply_score  demand_score
# 0    94022          50.61         69.26         31.96
# 1    94025          55.30         80.53         30.06
# 2    94028          41.71         56.53         26.90
# 3    94040          50.48         89.30         11.66
# 4    94043          53.30         91.16         15.43

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(housing_final_df_v1, 'housing_final_df_v1.csv', datapath)

# %% [markdown]
# ### 1.5.8 df_main_sold_houses wrangling<a id='1.5.8_df_main_sold_houses_wrangling'></a>

# %%
df_main_sold_houses.head()
# Out:
#    SALE TYPE          SOLD DATE              PROPERTY TYPE  \
# 0  PAST SALE  September-15-2020                Condo/Co-op
# 1  PAST SALE       July-14-2020                  Townhouse
# 2  PAST SALE        July-9-2020                Condo/Co-op
# 3  PAST SALE  September-29-2020  Single Family Residential
# 4  PAST SALE       July-14-2020  Single Family Residential
#
#               ADDRESS        CITY STATE OR PROVINCE ZIP OR POSTAL CODE  \
# 0   6985 Calistoga Ln      Dublin                CA              94568
# 1  270 Birch Creek Dr  Pleasanton                CA              94566
# 2   5324 Brookside Ct  Pleasanton                CA              94588
# 3   4385 Clovewood Ln  Pleasanton                CA         94588-4431
# 4      4273 Trolan Ln      Dublin                CA              94568
#
#      PRICE  BEDS  BATHS  ... STATUS  NEXT OPEN HOUSE START TIME  \
# 0   905000   3.0    3.5  ...   Sold                         NaN
# ...

# %%
df_main_sold_houses.columns.unique()
# Out:
# Index(['SALE TYPE', 'SOLD DATE', 'PROPERTY TYPE', 'ADDRESS', 'CITY',
#        'STATE OR PROVINCE', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS',
#        'LOCATION', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',
#        '$/SQUARE FEET', 'HOA/MONTH', 'STATUS', 'NEXT OPEN HOUSE START TIME',
#        'NEXT OPEN HOUSE END TIME',
#        'URL (SEE http://www.redfin.com/buy-a-home/comparative-market-analysis FOR INFO ON PRICING)',
#        'SOURCE', 'MLS#', 'FAVORITE', 'INTERESTED', 'LATITUDE', 'LONGITUDE'],
#       dtype='object')

# %% [markdown]
# #### 1.5.8.1 df_main_sold_houses Wrangling Summary<a id='1.5.8.1_df_main_sold_houses_Wrangling_Summary'></a>
#
# #### df_main_sold_houses DataFrame:
#    * For this dataFrame, we need to keep below columns:
# 'PROPERTY TYPE', 'ADDRESS', 'CITY', 'ZIP OR POSTAL CODE', 'PRICE', 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET',  '$/SQUARE FEET', 'HOA/MONTH', 'LATITUDE', 'LONGITUDE'
#    * let's make sure no NANs , no duplicates , no wrong values and we have the correct datatype in the above columns
#    * let's convert 'YEAR BUILT' to 'property_age'.
#    * let's rename all the columns.

# %%
df_main_sold_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8791 entries, 0 to 8790
# Data columns (total 27 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   SALE TYPE                                                                                   8791 non-null   object
#  1   SOLD DATE                                                                                   8241 non-null   object
#  2   PROPERTY TYPE                                                                               8791 non-null   object
#  3   ADDRESS                                                                                     8789 non-null   object
#  4   CITY                                                                                        8791 non-null   object
# ...

# %% [markdown]
# #### 1.5.8.2 Drop Insignificant Columns<a id='1.5.8.2_Drop_Insignificant_Columns'></a>

# %%
df_main_sold_houses = df_main_sold_houses.iloc[:,[2,3,4,5,6,7,8,9,11,12,13,14,15,16,25,26]]

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      Dublin
# 1                  Townhouse  270 Birch Creek Dr  Pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  Pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  Pleasanton
# 4  Single Family Residential      4273 Trolan Ln      Dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA         94588-4431  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
df_main_sold_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8791 entries, 0 to 8790
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PROPERTY TYPE       8791 non-null   object
#  1   ADDRESS             8789 non-null   object
#  2   CITY                8791 non-null   object
#  3   STATE OR PROVINCE   8791 non-null   object
#  4   ZIP OR POSTAL CODE  8791 non-null   object
#  5   PRICE               8791 non-null   int64
#  6   BEDS                8666 non-null   float64
#  7   BATHS               8645 non-null   float64
#  8   SQUARE FEET         8689 non-null   float64
#  9   LOT SIZE            7447 non-null   float64
#  10  YEAR BUILT          8588 non-null   float64
#  11  DAYS ON MARKET      8241 non-null   float64
#  12  $/SQUARE FEET       8676 non-null   float64
#  13  HOA/MONTH           3323 non-null   float64
#  14  LATITUDE            8791 non-null   float64
# ...

# %% [markdown]
# #### As we can see above, we have alot of NANs, so let's investigate:

# %%
#Let's investigate the NANs in our Dataframe:
missing = pd.concat([df_main_sold_houses.isnull().sum(), 100 * df_main_sold_houses.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                     count          %
# HOA/MONTH            5468  62.199977
# LOT SIZE             1344  15.288363
# DAYS ON MARKET        550   6.256399
# YEAR BUILT            203   2.309180
# BATHS                 146   1.660789
# BEDS                  125   1.421909
# $/SQUARE FEET         115   1.308156
# SQUARE FEET           102   1.160278
# ADDRESS                 2   0.022751
# PROPERTY TYPE           0   0.000000
# CITY                    0   0.000000
# STATE OR PROVINCE       0   0.000000
# ZIP OR POSTAL CODE      0   0.000000
# PRICE                   0   0.000000
# LATITUDE                0   0.000000
# LONGITUDE               0   0.000000

# %% [markdown]
# #### 1.5.8.3 Imputing NANs and Wrong Values<a id='1.5.8.3_Imputing_NANs_Wrong_Values'></a>
#
# #### NULL values summary:
#    1. **HOA/MONTH with over 62% missing**: This suggest that we have 62% of sold houses are having no HOAs so this means we can impute the missing values with zero.
#    2. **LOT SIZE with over 15% missing**: This suggest that we have 15% of the houses are either condos, townhouses or apartments so this means we can impute the missing values with zero.
#    3. Regarding the missing values at "DAYS ON MARKET", "YEAR BUILT", "BATHS", "BEDS", "$/SQUARE FEET", "SQUARE FEET" we can impute with the median.

# %% [markdown]
# #### But first let's investigate if we have any wrong values!!

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      Dublin
# 1                  Townhouse  270 Birch Creek Dr  Pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  Pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  Pleasanton
# 4  Single Family Residential      4273 Trolan Ln      Dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA         94588-4431  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
#let's investigate wrong zip codes, so we'll filter zipcode > 5:
df_main_sold_houses[df_main_sold_houses["ZIP OR POSTAL CODE"].apply(lambda x: len(x) > 5)]
# Out:
#                   PROPERTY TYPE                ADDRESS        CITY  \
# 3     Single Family Residential      4385 Clovewood Ln  Pleasanton
# 6     Single Family Residential     7370 Yountville St      Dublin
# 15    Single Family Residential          340 Mullin Ct  Pleasanton
# 85    Single Family Residential         1039 Nelson Ct  Pleasanton
# 135    Mobile/Manufactured Home  3231 Vineyard Ave #36  Pleasanton
# ...                         ...                    ...         ...
# 8772                Vacant Land      000 Bear Creek Rd    Martinez
# 8776  Single Family Residential         2131 Rock Pass    Martinez
# 8780                  Townhouse           1576 Ashwood    Martinez
# 8786  Single Family Residential     2201 Forsythia Way    Martinez
# 8789  Single Family Residential           6 Benita Way    Martinez
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 3                   CA         94588-4431  1036000   3.0    2.0       1355.0
# ...

# %% [markdown]
# #### So we have 397 zipcodes > 5 and this need to be corrected:

# %%
#let's remove any leading or trainling spaces in "ZIP OR POSTAL CODE":
df_main_sold_houses["ZIP OR POSTAL CODE"] = df_main_sold_houses["ZIP OR POSTAL CODE"].str.strip()
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      Dublin
# 1                  Townhouse  270 Birch Creek Dr  Pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  Pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  Pleasanton
# 4  Single Family Residential      4273 Trolan Ln      Dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA         94588-4431  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Now let's extract the five digits from the left of "ZIP OR POSTAL CODE":
df_main_sold_houses["ZIP OR POSTAL CODE"] = df_main_sold_houses["ZIP OR POSTAL CODE"].str[:6]
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# let's confirm no zipcodes exist with more than 5 digits:
df_main_sold_houses[df_main_sold_houses["ZIP OR POSTAL CODE"].apply(lambda x: len(x) > 5)]
# Out:
#                   PROPERTY TYPE                ADDRESS        CITY  \
# 3     Single Family Residential      4385 Clovewood Ln  Pleasanton
# 6     Single Family Residential     7370 Yountville St      Dublin
# 15    Single Family Residential          340 Mullin Ct  Pleasanton
# 85    Single Family Residential         1039 Nelson Ct  Pleasanton
# 135    Mobile/Manufactured Home  3231 Vineyard Ave #36  Pleasanton
# ...                         ...                    ...         ...
# 8772                Vacant Land      000 Bear Creek Rd    Martinez
# 8776  Single Family Residential         2131 Rock Pass    Martinez
# 8780                  Townhouse           1576 Ashwood    Martinez
# 8786  Single Family Residential     2201 Forsythia Way    Martinez
# 8789  Single Family Residential           6 Benita Way    Martinez
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 3                   CA             94588-  1036000   3.0    2.0       1355.0
# ...

# %%
#let's remove "-" in "ZIP OR POSTAL CODE":
df_main_sold_houses["ZIP OR POSTAL CODE"] = df_main_sold_houses["ZIP OR POSTAL CODE"].str.strip('-')
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# let's confirm no zipcodes exist with more than 5 digits:
df_main_sold_houses[df_main_sold_houses["ZIP OR POSTAL CODE"].apply(lambda x: len(x) > 5)]
# Out:
# Empty DataFrame
# Columns: [PROPERTY TYPE, ADDRESS, CITY, STATE OR PROVINCE, ZIP OR POSTAL CODE, PRICE, BEDS, BATHS, SQUARE FEET, LOT SIZE, YEAR BUILT, DAYS ON MARKET, $/SQUARE FEET, HOA/MONTH, LATITUDE, LONGITUDE]
# Index: []

# %% [markdown]
# #### Now no zipcodes > 5 digits !!
#
#
# #### let's check some wrong values at "ZIP OR POSTAL CODE"

# %%
#let's check the zipcodes: 
df_main_sold_houses["ZIP OR POSTAL CODE"].sort_values(ascending=True)
# Out:
# 5929    75154
# 2315    94022
# 2125    94022
# 2126    94022
# 2238    94022
#         ...
# 1773    95134
# 1082    95468
# 1326    95468
# 1237    95468
# 6661    95468
# Name: ZIP OR POSTAL CODE, Length: 8791, dtype: object

# %%
# zipcode 75154 is wrong (Not in California) and the correct value should be 94553 after checking the address below:
df_main_sold_houses.iloc[5929]
# Out:
# PROPERTY TYPE         Single Family Residential
# ADDRESS                          1126 Henrietta
# CITY                                   Martinez
# STATE OR PROVINCE                            CA
# ZIP OR POSTAL CODE                        75154
# PRICE                                    385000
# BEDS                                          1
# BATHS                                         1
# SQUARE FEET                                 680
# LOT SIZE                                   2500
# YEAR BUILT                                 1936
# DAYS ON MARKET                               51
# $/SQUARE FEET                               566
# HOA/MONTH                                   NaN
# LATITUDE                                38.0163
# LONGITUDE                              -122.131
# Name: 5929, dtype: object

# %%
# let's correct the zipcode:
df_main_sold_houses.iloc[5929,4] = '94553'
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_main_sold_houses.iloc[5929,4]
# Out:
# '94553'

# %%
#let's check the zipcodes: 
df_main_sold_houses["ZIP OR POSTAL CODE"].sort_values(ascending=True)
# Out:
# 2097    94022
# 2217    94022
# 2191    94022
# 2299    94022
# 2300    94022
#         ...
# 1773    95134
# 1082    95468
# 1326    95468
# 1237    95468
# 6661    95468
# Name: ZIP OR POSTAL CODE, Length: 8791, dtype: object

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      Dublin
# 1                  Townhouse  270 Birch Creek Dr  Pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  Pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  Pleasanton
# 4  Single Family Residential      4273 Trolan Ln      Dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# ##### Now let's explore the data in more depth to see if any values will need any correction before we start working in NANs:

# %%
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Vacant Land', 'Mobile/Manufactured Home',
#        'Multi-Family (2-4 Unit)', 'Unknown', 'Multi-Family (5+ Unit)',
#        'Other'], dtype=object)

# %%
df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Other']
# Out:
#      PROPERTY TYPE                   ADDRESS      CITY STATE OR PROVINCE  \
# 4257         Other        25697 Mission Blvd   Hayward                CA
# 6480         Other           5411 Alvar Loop   Antioch                CA
# 6609         Other                 Neroly Rd   Antioch                CA
# 7064         Other            196 Joaquin Dr  DANVILLE                CA
# 7307         Other  2300 Caballo Ranchero Dr    DIABLO                CA
#
#      ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET   LOT SIZE  \
# 4257              94544  3100000  10.0    9.0       5216.0    49031.0
# 6480              94531   584500   NaN    NaN          NaN        NaN
# 6609              94531   154000   NaN    NaN          NaN   144837.0
# 7064              94526   810000   3.0    2.5       1470.0     5400.0
# 7307              94528  4000000   NaN    NaN          NaN  2514283.0
#
#       YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Unknown']
# Out:
#      PROPERTY TYPE            ADDRESS         CITY STATE OR PROVINCE  \
# 649        Unknown   1910 Mayette Ave      Concord                CA
# 1947       Unknown  687 Los Olivos Dr  Santa Clara                CA
#
#      ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  \
# 649               94520   590000   3.0    2.0       1035.0    5700.0
# 1947              95050  1259000   1.0    1.0       1087.0    6042.0
#
#       YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# 649       1957.0           160.0          570.0        NaN  37.962232
# 1947      1954.0             NaN         1158.0        NaN  37.338736
#
#        LONGITUDE
# 649  -122.046370
# 1947 -121.965041

# %%
df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Vacant Land']
# Out:
#      PROPERTY TYPE                    ADDRESS           CITY  \
# 55     Vacant Land              1851 Rose Ave     Pleasanton
# 63     Vacant Land            3747 Trenery Dr     Pleasanton
# 230    Vacant Land             6443 Alisal St     Pleasanton
# 2659   Vacant Land  0 Arroyo Road/Ascalano Ln      LIVERMORE
# 2670   Vacant Land                00 Foley Rd      Livermore
# ...            ...                        ...            ...
# 8618   Vacant Land                0 S 15Th St       Richmond
# 8619   Vacant Land        21 Avenida Martinez    El Sobrante
# 8771   Vacant Land          800 Golf Club Cir  Pleasant Hill
# 8772   Vacant Land          000 Bear Creek Rd       Martinez
# 8773   Vacant Land          0 Garcia Ranch Rd       Martinez
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 55                  CA              94566   635000   NaN    NaN          NaN
# ...

# %%
df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Mobile/Manufactured Home']
# Out:
#                  PROPERTY TYPE                  ADDRESS        CITY  \
# 135   Mobile/Manufactured Home    3231 Vineyard Ave #36  Pleasanton
# 196   Mobile/Manufactured Home       3263 Vineyard #198  Pleasanton
# 197   Mobile/Manufactured Home    3263 Vineyard Ave #48  Pleasanton
# 198   Mobile/Manufactured Home  3263 Vineyard Ave., #66  Pleasanton
# 203   Mobile/Manufactured Home   3263 Vineyard Ave #175  Pleasanton
# ...                        ...                      ...         ...
# 8726  Mobile/Manufactured Home    306 Vista Del Rio #43     Pacheco
# 8767  Mobile/Manufactured Home            237 Hieber Dr     Pacheco
# 8768  Mobile/Manufactured Home             252 Sinai Dr     Pacheco
# 8774  Mobile/Manufactured Home             14 Barika Ct     Pacheco
# 8775  Mobile/Manufactured Home            160 Sahara Dr     Pacheco
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# ...

# %% [markdown]
# #### 'PROPERTY TYPE' :
# 'Other', 'Unknown', 'Vacant Land' and 'Mobile/Manufactured Home' ***can be dropped because no values on them for such project***
# * 200 rows will be dropped!

# %%
#let's check unique 'PROPERTY TYPE':
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Vacant Land', 'Mobile/Manufactured Home',
#        'Multi-Family (2-4 Unit)', 'Unknown', 'Multi-Family (5+ Unit)',
#        'Other'], dtype=object)

# %%
# Get indexes where name column has value 'Vacant Land':
indexNames = df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Vacant Land'].index

# %%
# Delete these row indexes from dataFrame:
df_main_sold_houses.drop(indexNames , inplace=True)
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\frame.py:4174: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
#let's confirm unique 'PROPERTY TYPE':
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Mobile/Manufactured Home', 'Multi-Family (2-4 Unit)', 'Unknown',
#        'Multi-Family (5+ Unit)', 'Other'], dtype=object)

# %%
# Get indexes where name column has value 'Mobile/Manufactured Home':
indexNames = df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Mobile/Manufactured Home'].index

# %%
# Delete these row indexes from dataFrame:
df_main_sold_houses.drop(indexNames , inplace=True)

# %%
#let's confirm unique 'PROPERTY TYPE':
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Multi-Family (2-4 Unit)', 'Unknown', 'Multi-Family (5+ Unit)',
#        'Other'], dtype=object)

# %%
# Get indexes where name column has value Unknown':
indexNames = df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Unknown'].index

# %%
# Delete these row indexes from dataFrame:
df_main_sold_houses.drop(indexNames , inplace=True)

# %%
#let's confirm unique 'PROPERTY TYPE':
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Multi-Family (2-4 Unit)', 'Multi-Family (5+ Unit)', 'Other'],
#       dtype=object)

# %%
# Get indexes where name column has value 'Other':
indexNames = df_main_sold_houses[df_main_sold_houses['PROPERTY TYPE'] == 'Other'].index

# %%
# Delete these row indexes from dataFrame:
df_main_sold_houses.drop(indexNames , inplace=True)

# %%
#let's confirm unique 'PROPERTY TYPE':
df_main_sold_houses['PROPERTY TYPE'].unique()
# Out:
# array(['Condo/Co-op', 'Townhouse', 'Single Family Residential',
#        'Multi-Family (2-4 Unit)', 'Multi-Family (5+ Unit)'], dtype=object)

# %% [markdown]
# #### 'Other', 'Unknown', 'Vacant Land' and 'Mobile/Manufactured Home'
# **All dropped**

# %%
df_main_sold_houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8591 entries, 0 to 8790
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PROPERTY TYPE       8591 non-null   object
#  1   ADDRESS             8590 non-null   object
#  2   CITY                8591 non-null   object
#  3   STATE OR PROVINCE   8591 non-null   object
#  4   ZIP OR POSTAL CODE  8591 non-null   object
#  5   PRICE               8591 non-null   int64
#  6   BEDS                8547 non-null   float64
#  7   BATHS               8527 non-null   float64
#  8   SQUARE FEET         8571 non-null   float64
#  9   LOT SIZE            7364 non-null   float64
#  10  YEAR BUILT          8569 non-null   float64
#  11  DAYS ON MARKET      8064 non-null   float64
#  12  $/SQUARE FEET       8558 non-null   float64
#  13  HOA/MONTH           3319 non-null   float64
#  14  LATITUDE            8591 non-null   float64
# ...

# %%
df_main_sold_houses['CITY'].unique()
# Out:
# array(['Dublin', 'Pleasanton', 'PLEASANTON', 'DUBLIN', 'Sunol', 'Concord',
#        'Pleasant Hill', 'Clayton', 'CONCORD', 'Walnut Creek', 'Danville',
#        'San Ramon', 'DANVILLE', 'Diablo', 'SAN RAMON', 'Santa Clara',
#        'SUNNYVALE', 'SANTA CLARA', 'SAN JOSE', 'Sunnyvale', 'San Jose',
#        'LOS ALTOS', 'Palo Alto', 'PALO ALTO', 'EAST PALO ALTO',
#        'MENLO PARK', 'Stanford', 'MOUNTAIN VIEW', 'PORTOLA VALLEY',
#        'LOS ALTOS HILLS', 'Mountain View', 'Los Altos Hills', 'Los Altos',
#        'Menlo Park', 'STANFORD', 'Livermore', 'LIVERMORE', 'WALNUT CREEK',
#        'Lafayette', 'PLEASANT HILL', 'Martinez', 'Pacheco', 'Oakland',
#        'Emeryville', 'Berkeley', 'San Leandro', 'OAKLAND', 'Piedmont',
#        'Alameda', 'SAN LEANDRO', 'Castro Valley', 'San Lorenzo',
#        'Hayward', 'HAYWARD', 'Union City', 'SAN LORENZO', 'CASTRO VALLEY',
#        'BERKELEY', 'Kensington', 'KENSINGTON', 'ALBANY', 'Albany',
# ...

# %% [markdown]
# #### Checking the CITY column:
#   1. We can see that some cities are UPPERCASE and some are LOWERCASE --> So let's lowercase all this column.
#   2. 'Unincorporated' city --> let's investigate in this one

# %%
# First let's lowercase the "CITY" column: 
df_main_sold_houses['CITY'] = df_main_sold_houses['CITY'].str.lower()
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_main_sold_houses['CITY'].unique()
# Out:
# array(['dublin', 'pleasanton', 'sunol', 'concord', 'pleasant hill',
#        'clayton', 'walnut creek', 'danville', 'san ramon', 'diablo',
#        'santa clara', 'sunnyvale', 'san jose', 'los altos', 'palo alto',
#        'east palo alto', 'menlo park', 'stanford', 'mountain view',
#        'portola valley', 'los altos hills', 'livermore', 'lafayette',
#        'martinez', 'pacheco', 'oakland', 'emeryville', 'berkeley',
#        'san leandro', 'piedmont', 'alameda', 'castro valley',
#        'san lorenzo', 'hayward', 'union city', 'kensington', 'albany',
#        'richmond', 'el cerrito', 'el sobrante', 'san pablo',
#        'point richmond', 'pittsburg', 'bay point', 'antioch', 'oakley',
#        'brentwood', 'alamo', 'unincorporated'], dtype=object)

# %% [markdown]
# #### 'CITY' Column looks much better now
#
# #### let's investigate 'unincorporated' city name and let's see if we can impute with the correct city name

# %%
df_main_sold_houses[df_main_sold_houses['CITY'] == 'unincorporated']
# Out:
#                   PROPERTY TYPE        ADDRESS            CITY  \
# 7299  Single Family Residential  24 Holiday Dr  unincorporated
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 7299                CA              94507  2380000   5.0   2.75       2994.0
#
#       LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  \
# 7299   22100.0      1954.0            82.0          795.0        NaN
#
#        LATITUDE   LONGITUDE
# 7299  37.840354 -122.034356

# %% [markdown]
# #### After looking at the address associated to 'unincorporated' city --> we can correct with with alamo

# %%
df_main_sold_houses['CITY'].unique()
# Out:
# array(['dublin', 'pleasanton', 'sunol', 'concord', 'pleasant hill',
#        'clayton', 'walnut creek', 'danville', 'san ramon', 'diablo',
#        'santa clara', 'sunnyvale', 'san jose', 'los altos', 'palo alto',
#        'east palo alto', 'menlo park', 'stanford', 'mountain view',
#        'portola valley', 'los altos hills', 'livermore', 'lafayette',
#        'martinez', 'pacheco', 'oakland', 'emeryville', 'berkeley',
#        'san leandro', 'piedmont', 'alameda', 'castro valley',
#        'san lorenzo', 'hayward', 'union city', 'kensington', 'albany',
#        'richmond', 'el cerrito', 'el sobrante', 'san pablo',
#        'point richmond', 'pittsburg', 'bay point', 'antioch', 'oakley',
#        'brentwood', 'alamo', 'unincorporated'], dtype=object)

# %%
#let's confirm:
df_main_sold_houses.at[7299,'CITY']
# Out:
# 'unincorporated'

# %%
#let's update city name 'unincorporated' with the correct city name: 'alamo'
df_main_sold_houses.at[7299,'CITY'] = 'alamo'

# %%
#let's confirm:
df_main_sold_houses['CITY'].unique()
# Out:
# array(['dublin', 'pleasanton', 'sunol', 'concord', 'pleasant hill',
#        'clayton', 'walnut creek', 'danville', 'san ramon', 'diablo',
#        'santa clara', 'sunnyvale', 'san jose', 'los altos', 'palo alto',
#        'east palo alto', 'menlo park', 'stanford', 'mountain view',
#        'portola valley', 'los altos hills', 'livermore', 'lafayette',
#        'martinez', 'pacheco', 'oakland', 'emeryville', 'berkeley',
#        'san leandro', 'piedmont', 'alameda', 'castro valley',
#        'san lorenzo', 'hayward', 'union city', 'kensington', 'albany',
#        'richmond', 'el cerrito', 'el sobrante', 'san pablo',
#        'point richmond', 'pittsburg', 'bay point', 'antioch', 'oakley',
#        'brentwood', 'alamo'], dtype=object)

# %% [markdown]
# #### Alright, now all values @ "City' Column is fixed

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
df_main_sold_houses['ZIP OR POSTAL CODE'].unique()
# Out:
# array(['94568', '94566', '94588', '94563', '94586', '94519', '94521',
#        '94523', '94520', '94517', '94518', '94598', '94597', '94506',
#        '94526', '94582', '94583', '95468', '95051', '94086', '95050',
#        '95117', '95054', '95128', '94089', '95126', '94087', '95129',
#        '94022', '94303', '94306', '94304', '94301', '94025', '94305',
#        '94040', '94028', '94043', '94551', '94550', '94595', '94596',
#        '94549', '94553', '94619', '94606', '94609', '94605', '94611',
#        '94602', '94618', '94608', '94705', '94603', '94607', '94601',
#        '94612', '94621', '94610', '94577', '94702', '94703', '94579',
#        '94578', '94546', '94580', '94541', '94542', '94544', '94545',
#        '94587', '94552', '94704', '94706', '94710', '94707', '94708',
#        '94709', '94805', '94804', '94530', '94801', '94803', '94806',
#        '94508', '94533', '94565', '94509', '94561', '94531', '94513',
#        '94507', '94528'], dtype=object)

# %%
df_main_sold_houses[(df_main_sold_houses['CITY'] == 'dublin') & (df_main_sold_houses['ZIP OR POSTAL CODE'] != '94568')][['CITY','ZIP OR POSTAL CODE']]
# Out:
#         CITY ZIP OR POSTAL CODE
# 6     dublin              94563
# 1082  dublin              95468
# 1090  dublin              94563
# 1237  dublin              95468
# 1269  dublin              94588
# 1326  dublin              95468
# 6661  dublin              95468
# 6733  dublin              94588

# %% [markdown]
# #### So as we can see above, the city of dublin has only one zipcode which is 94568, so all these houses need to corrected

# %%
df_main_sold_houses.iloc[6,4]
# Out:
# '94563'

# %%
df_main_sold_houses.iloc[6,4] = '94568'
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\pandas\core\indexing.py:1763: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_main_sold_houses.iloc[6,4]
# Out:
# '94568'

# %%
df_main_sold_houses[(df_main_sold_houses['CITY'] == 'dublin') & (df_main_sold_houses['ZIP OR POSTAL CODE'] != '94568')][['CITY','ZIP OR POSTAL CODE']]
# Out:
#         CITY ZIP OR POSTAL CODE
# 1082  dublin              95468
# 1090  dublin              94563
# 1237  dublin              95468
# 1269  dublin              94588
# 1326  dublin              95468
# 6661  dublin              95468
# 6733  dublin              94588

# %%
df_main_sold_houses.at[1082,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[1090,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[1237,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[1269,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[1326,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[6661,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses.at[6733,'ZIP OR POSTAL CODE'] = '94568'

# %%
df_main_sold_houses['ZIP OR POSTAL CODE'].unique()
# Out:
# array(['94568', '94566', '94588', '94586', '94519', '94521', '94523',
#        '94520', '94517', '94518', '94598', '94597', '94506', '94526',
#        '94582', '94583', '95051', '94086', '95050', '95117', '95054',
#        '95128', '94089', '95126', '94087', '95129', '94022', '94303',
#        '94306', '94304', '94301', '94025', '94305', '94040', '94028',
#        '94043', '94551', '94550', '94595', '94596', '94549', '94553',
#        '94563', '94619', '94606', '94609', '94605', '94611', '94602',
#        '94618', '94608', '94705', '94603', '94607', '94601', '94612',
#        '94621', '94610', '94577', '94702', '94703', '94579', '94578',
#        '94546', '94580', '94541', '94542', '94544', '94545', '94587',
#        '94552', '94704', '94706', '94710', '94707', '94708', '94709',
#        '94805', '94804', '94530', '94801', '94803', '94806', '94508',
#        '94533', '94565', '94509', '94561', '94531', '94513', '94507',
#        '94528'], dtype=object)

# %%
df_main_sold_houses[(df_main_sold_houses['CITY'] == 'dublin') & (df_main_sold_houses['ZIP OR POSTAL CODE'] != '94568')][['CITY','ZIP OR POSTAL CODE']]
# Out:
# Empty DataFrame
# Columns: [CITY, ZIP OR POSTAL CODE]
# Index: []

# %% [markdown]
# #### City dublin and zipcodes got fixed

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# #### now let's deal with NANs:

# %%
#Let's investigate the NANs in our Dataframe:
missing = pd.concat([df_main_sold_houses.isnull().sum(), 100 * df_main_sold_houses.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                     count          %
# HOA/MONTH            5272  61.366546
# LOT SIZE             1227  14.282389
# DAYS ON MARKET        527   6.134327
# BATHS                  64   0.744966
# BEDS                   44   0.512164
# $/SQUARE FEET          33   0.384123
# YEAR BUILT             22   0.256082
# SQUARE FEET            20   0.232802
# ADDRESS                 1   0.011640
# PROPERTY TYPE           0   0.000000
# CITY                    0   0.000000
# STATE OR PROVINCE       0   0.000000
# ZIP OR POSTAL CODE      0   0.000000
# PRICE                   0   0.000000
# LATITUDE                0   0.000000
# LONGITUDE               0   0.000000

# %% [markdown]
# #### NULL values summary:
#    1. **HOA/MONTH with over 62% missing**: This suggest that we have 62% of sold houses are having no HOAs so this means we can impute the missing values with zero.
#    2. **LOT SIZE with over 15% missing**: This suggest that we have 15% of the houses are either condos, townhouses or apartments so this means we can impute the missing values with zero.
#    3. Regarding the missing values at "DAYS ON MARKET", "YEAR BUILT", "BATHS", "BEDS", "$/SQUARE FEET", "SQUARE FEET" we can impute with the median.

# %%
df_main_sold_houses.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# let's first start with "HOA/MONTH", let's impute the missing values with the "0" indicating that there's no HOA:
df_main_sold_houses_imputed = df_main_sold_houses.fillna({'HOA/MONTH': 0})
df_main_sold_houses_imputed.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# let's first start with "LOT SIZE", let's impute the missing values with the "0" indicating that these proprties are not a single home:
df_main_sold_houses_imputed_1 = df_main_sold_houses_imputed.fillna({'LOT SIZE': 0})
df_main_sold_houses_imputed_1.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# #### Regarding the missing values at "DAYS ON MARKET", "YEAR BUILT", "BATHS", "BEDS", "$/SQUARE FEET", "SQUARE FEET" we can impute with the median.

# %%
# let's first start with "DAYS ON MARKET", let's impute the missing values with the median:
imputed_median_1 = df_main_sold_houses_imputed_1['DAYS ON MARKET'].median()
df_main_sold_houses_imputed_2 = df_main_sold_houses_imputed_1.fillna({'DAYS ON MARKET': imputed_median_1})
df_main_sold_houses_imputed_2.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Next "YEAR BUILT", let's impute the missing values with the median:
imputed_median_2 = df_main_sold_houses_imputed_2['YEAR BUILT'].median()
df_main_sold_houses_imputed_3 = df_main_sold_houses_imputed_2.fillna({'YEAR BUILT': imputed_median_2})
df_main_sold_houses_imputed_3.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Next "BATHS", let's impute the missing values with the median:
imputed_median_3 = df_main_sold_houses_imputed_3['BATHS'].median()
df_main_sold_houses_imputed_4 = df_main_sold_houses_imputed_3.fillna({'BATHS': imputed_median_3})
df_main_sold_houses_imputed_4.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Next "BEDS", let's impute the missing values with the median:
imputed_median_4 = df_main_sold_houses_imputed_4['BEDS'].median()
df_main_sold_houses_imputed_5 = df_main_sold_houses_imputed_4.fillna({'BEDS': imputed_median_4})
df_main_sold_houses_imputed_5.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Next "$/SQUARE FEET", let's impute the missing values with the median:
imputed_median_5 = df_main_sold_houses_imputed_5['$/SQUARE FEET'].median()
df_main_sold_houses_imputed_6 = df_main_sold_houses_imputed_5.fillna({'$/SQUARE FEET': imputed_median_5})
df_main_sold_houses_imputed_6.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
# Finally "SQUARE FEET", let's impute the missing values with the median:
imputed_median_6 = df_main_sold_houses_imputed_6['SQUARE FEET'].median()
df_main_sold_houses_imputed_7 = df_main_sold_houses_imputed_6.fillna({'SQUARE FEET': imputed_median_6})
df_main_sold_houses_imputed_7.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
df_main_sold_houses_final = df_main_sold_houses_imputed_7

# %%
#Let's check the NANs in our Dataframe:
missing = pd.concat([df_main_sold_houses_final.isnull().sum(), 100 * df_main_sold_houses_final.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                     count        %
# ADDRESS                 1  0.01164
# PROPERTY TYPE           0  0.00000
# CITY                    0  0.00000
# STATE OR PROVINCE       0  0.00000
# ZIP OR POSTAL CODE      0  0.00000
# PRICE                   0  0.00000
# BEDS                    0  0.00000
# BATHS                   0  0.00000
# SQUARE FEET             0  0.00000
# LOT SIZE                0  0.00000
# YEAR BUILT              0  0.00000
# DAYS ON MARKET          0  0.00000
# $/SQUARE FEET           0  0.00000
# HOA/MONTH               0  0.00000
# LATITUDE                0  0.00000
# LONGITUDE               0  0.00000

# %% [markdown]
# #### All imputed columns got fixed, we still have one Address is missing, so let's see what's going on!!

# %%
# After checking the long and lat we can see that the address is 2920 Mayflower Dr:
df_main_sold_houses_final[df_main_sold_houses_final['ADDRESS'].isnull()]
# Out:
#                   PROPERTY TYPE ADDRESS     CITY STATE OR PROVINCE  \
# 6474  Single Family Residential     NaN  antioch                CA
#
#      ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  LOT SIZE  \
# 6474              94531  538500   4.0    3.0       2175.0       0.0
#
#       YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH  LATITUDE  \
# 6474      2019.0           111.0          248.0        0.0   37.9903
#
#       LONGITUDE
# 6474  -121.7786

# %%
# Let's correct the address:
df_main_sold_houses_final.at[6474,'ADDRESS'] = '2920 Mayflower Dr'

# %%
#Let's check the NANs in our Dataframe:
missing = pd.concat([df_main_sold_houses_final.isnull().sum(), 100 * df_main_sold_houses_final.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                     count    %
# PROPERTY TYPE           0  0.0
# ADDRESS                 0  0.0
# CITY                    0  0.0
# STATE OR PROVINCE       0  0.0
# ZIP OR POSTAL CODE      0  0.0
# PRICE                   0  0.0
# BEDS                    0  0.0
# BATHS                   0  0.0
# SQUARE FEET             0  0.0
# LOT SIZE                0  0.0
# YEAR BUILT              0  0.0
# DAYS ON MARKET          0  0.0
# $/SQUARE FEET           0  0.0
# HOA/MONTH               0  0.0
# LATITUDE                0  0.0
# LONGITUDE               0  0.0

# %% [markdown]
# #### Now it's confirmed all NANs are fixed in this Dataframe

# %%
df_main_sold_houses_final.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# #### 1.5.8.4 Replacing Year Built Column with property_age<a id='1.5.8.4_Replacing_YearBuilt_Column_with_propert_age'></a>

# %%
#### let's replace 'YEAR BUILT' with 'property_age':
df_main_sold_houses_final['property_age'] = 2021 - df_main_sold_houses_final['YEAR BUILT']

# %%
df_main_sold_houses_final.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    3.5       1994.0
# 1                CA              94566   645000   2.0    2.5       1221.0
# 2                CA              94588   940000   4.0    2.5       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %%
df_main_sold_houses_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8591 entries, 0 to 8790
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PROPERTY TYPE       8591 non-null   object
#  1   ADDRESS             8591 non-null   object
#  2   CITY                8591 non-null   object
#  3   STATE OR PROVINCE   8591 non-null   object
#  4   ZIP OR POSTAL CODE  8591 non-null   object
#  5   PRICE               8591 non-null   int64
#  6   BEDS                8591 non-null   float64
#  7   BATHS               8591 non-null   float64
#  8   SQUARE FEET         8591 non-null   float64
#  9   LOT SIZE            8591 non-null   float64
#  10  YEAR BUILT          8591 non-null   float64
#  11  DAYS ON MARKET      8591 non-null   float64
#  12  $/SQUARE FEET       8591 non-null   float64
#  13  HOA/MONTH           8591 non-null   float64
#  14  LATITUDE            8591 non-null   float64
# ...

# %% [markdown]
# #### 1.5.8.5 Round Columns<a id='1.5.8.5_Round_Columns'></a>
#
# #### Let's round:
# 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH' and 'property_age' to decimel =0

# %%
#let's round 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH' and 'property_age':
df_main_sold_houses_final = df_main_sold_houses_final.round({'BEDS':0, 'BATHS':0, 'SQUARE FEET':0, 'LOT SIZE':0, 'YEAR BUILT':0, 'DAYS ON MARKET':0, '$/SQUARE FEET':0, 'HOA/MONTH':0,'property_age':0})

# %%
df_main_sold_houses_final.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000   3.0    4.0       1994.0
# 1                CA              94566   645000   2.0    2.0       1221.0
# 2                CA              94588   940000   4.0    2.0       1928.0
# 3                CA              94588  1036000   3.0    2.0       1355.0
# 4                CA              94568  1250000   4.0    4.0       3083.0
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# #### 1.5.8.6 Correcting Data Types<a id='1.5.8.6_Correcting_Data_Types'></a>
#
# #### Let's change datatype of below from float64 to int64:
# 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH' and 'property_age' to decimel =0

# %%
# let's change 'BEDS', 'BATHS', 'SQUARE FEET', 'LOT SIZE', 'YEAR BUILT', 'DAYS ON MARKET', '$/SQUARE FEET', 'HOA/MONTH' and 'property_age'  data type from 'float' to 'int':

df_main_sold_houses_final.iloc[:,[6,7,8,9,10,11,12,13,16]]  = df_main_sold_houses_final.iloc[:,[6,7,8,9,10,11,12,13,16]] .astype('int64')

# %%
df_main_sold_houses_final.dtypes
# Out:
# PROPERTY TYPE          object
# ADDRESS                object
# CITY                   object
# STATE OR PROVINCE      object
# ZIP OR POSTAL CODE     object
# PRICE                   int64
# BEDS                    int64
# BATHS                   int64
# SQUARE FEET             int64
# LOT SIZE                int64
# YEAR BUILT              int64
# DAYS ON MARKET          int64
# $/SQUARE FEET           int64
# HOA/MONTH               int64
# LATITUDE              float64
# LONGITUDE             float64
# property_age            int64
# dtype: object

# %%
df_main_sold_houses_final.head()
# Out:
#                PROPERTY TYPE             ADDRESS        CITY  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin
# 1                  Townhouse  270 Birch Creek Dr  pleasanton
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton
# 4  Single Family Residential      4273 Trolan Ln      dublin
#
#   STATE OR PROVINCE ZIP OR POSTAL CODE    PRICE  BEDS  BATHS  SQUARE FEET  \
# 0                CA              94568   905000     3      4         1994
# 1                CA              94566   645000     2      2         1221
# 2                CA              94588   940000     4      2         1928
# 3                CA              94588  1036000     3      2         1355
# 4                CA              94568  1250000     4      4         3083
#
#    LOT SIZE  YEAR BUILT  DAYS ON MARKET  $/SQUARE FEET  HOA/MONTH   LATITUDE  \
# ...

# %% [markdown]
# #### All Datatypes are corrected!
#
#
# #### 1.5.8.7 Dealing with Duplicates<a id='1.5.8.7_Dealing_with_Duplicates'></a>
#
# #### Finally let's make sure no duplicates in the address:

# %%
# So let's find if we have any duplicates on the 'Address':
duplicates = df_main_sold_houses_final.duplicated(subset='ADDRESS', keep=False)
df_main_sold_houses_final[duplicates].sort_values(by = 'ADDRESS')
# Out:
#                   PROPERTY TYPE             ADDRESS           CITY  \
# 5620                  Townhouse  1 Heritage Oaks Rd  pleasant hill
# 3172                  Townhouse  1 Heritage Oaks Rd  pleasant hill
# 674                 Condo/Co-op   103 Glenbridge Ct  pleasant hill
# 3147                Condo/Co-op   103 Glenbridge Ct  pleasant hill
# 427                   Townhouse    1032 Bancroft Rd        concord
# ...                         ...                 ...            ...
# 3178  Single Family Residential        98 Deodar Dr        pacheco
# 5933  Single Family Residential        98 Deodar Dr        pacheco
# 4590  Single Family Residential            BAKER RD  castro valley
# 4593  Single Family Residential            BAKER RD  castro valley
# 4594  Single Family Residential            BAKER RD  castro valley
#
#      STATE OR PROVINCE ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  SQUARE FEET  \
# 5620                CA              94523  699000     1      4         1999
# ...

# %% [markdown]
# #### According to the above we have 470 observations where we have a complete duplicates meaning the observations have equal variables and in such case we should be dropping all of these duplicates!!!

# %%
# let's drop duplicates:
df_main_sold_houses_final.drop_duplicates(inplace=True)

# %%
df_main_sold_houses_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8472 entries, 0 to 8790
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   PROPERTY TYPE       8472 non-null   object
#  1   ADDRESS             8472 non-null   object
#  2   CITY                8472 non-null   object
#  3   STATE OR PROVINCE   8472 non-null   object
#  4   ZIP OR POSTAL CODE  8472 non-null   object
#  5   PRICE               8472 non-null   int64
#  6   BEDS                8472 non-null   int64
#  7   BATHS               8472 non-null   int64
#  8   SQUARE FEET         8472 non-null   int64
#  9   LOT SIZE            8472 non-null   int64
#  10  YEAR BUILT          8472 non-null   int64
#  11  DAYS ON MARKET      8472 non-null   int64
#  12  $/SQUARE FEET       8472 non-null   int64
#  13  HOA/MONTH           8472 non-null   int64
#  14  LATITUDE            8472 non-null   float64
# ...

# %% [markdown]
# #### 1.5.8.8 Renaming Columns<a id='1.5.8.8_Renaming_Columns'></a>
#
# #### Now let's rename the columns correctly:

# %%
# Now let's Give all columns a new lablel names:
df_main_sold_houses_final.rename(columns = {list(df_main_sold_houses_final)[0]: 'property_name', 
                                            list(df_main_sold_houses_final)[1]: 'address',
                                            list(df_main_sold_houses_final)[2]: 'city',
                                            list(df_main_sold_houses_final)[3]: 'state',
                                            list(df_main_sold_houses_final)[4]: 'zipcode',
                                            list(df_main_sold_houses_final)[5]: 'price',
                                            list(df_main_sold_houses_final)[6]: 'beds',
                                            list(df_main_sold_houses_final)[7]: 'baths',
                                            list(df_main_sold_houses_final)[8]: 'sqft',
                                            list(df_main_sold_houses_final)[9]: 'lot_size',
                                            list(df_main_sold_houses_final)[10]: 'year_built',
                                            list(df_main_sold_houses_final)[11]: 'days_on_market',
                                            list(df_main_sold_houses_final)[12]: 'price_per_sqft',
                                            list(df_main_sold_houses_final)[13]: 'hoa_month',
                                            list(df_main_sold_houses_final)[14]: 'lat',
                                            list(df_main_sold_houses_final)[15]: 'long',
                                            list(df_main_sold_houses_final)[16]: 'property_age'},inplace = True)

# %%
df_main_sold_houses_final.head()
# Out:
#                property_name             address        city state zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA   94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA   94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA   94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA   94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA   94568
#
#      price  beds  baths  sqft  lot_size  year_built  days_on_market  \
# 0   905000     3      4  1994         0        2018              80
# 1   645000     2      2  1221      1237        1986             143
# 2   940000     4      2  1928      2660        1981             148
# 3  1036000     3      2  1355      7708        1966              66
# 4  1250000     4      4  3083      3058        2017             143
#
#    price_per_sqft  hoa_month        lat        long  property_age
# ...

# %%
df_main_sold_houses_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8472 entries, 0 to 8790
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_name   8472 non-null   object
#  1   address         8472 non-null   object
#  2   city            8472 non-null   object
#  3   state           8472 non-null   object
#  4   zipcode         8472 non-null   object
#  5   price           8472 non-null   int64
#  6   beds            8472 non-null   int64
#  7   baths           8472 non-null   int64
#  8   sqft            8472 non-null   int64
#  9   lot_size        8472 non-null   int64
#  10  year_built      8472 non-null   int64
#  11  days_on_market  8472 non-null   int64
#  12  price_per_sqft  8472 non-null   int64
#  13  hoa_month       8472 non-null   int64
#  14  lat             8472 non-null   float64
#  15  long            8472 non-null   float64
#  16  property_age    8472 non-null   int64
# ...

# %% [markdown]
# #### Finally let's change 'zipcode' datatype from 'object' to 'int'

# %%
#change 'zipcode'datatype from 'object' to 'int':
df_main_sold_houses_final['zipcode'] = df_main_sold_houses_final['zipcode'].astype('int64')

df_main_sold_houses_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8472 entries, 0 to 8790
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   property_name   8472 non-null   object
#  1   address         8472 non-null   object
#  2   city            8472 non-null   object
#  3   state           8472 non-null   object
#  4   zipcode         8472 non-null   int64
#  5   price           8472 non-null   int64
#  6   beds            8472 non-null   int64
#  7   baths           8472 non-null   int64
#  8   sqft            8472 non-null   int64
#  9   lot_size        8472 non-null   int64
#  10  year_built      8472 non-null   int64
#  11  days_on_market  8472 non-null   int64
#  12  price_per_sqft  8472 non-null   int64
#  13  hoa_month       8472 non-null   int64
#  14  lat             8472 non-null   float64
#  15  long            8472 non-null   float64
#  16  property_age    8472 non-null   int64
# ...

# %% [markdown]
# #### Summary:
#   1. Duplicates dropped.
#   2. data types corrected.
#   3. wrong values corrected.
#   4. NANs imputed
#   5. columns labels corrected.
#   6. Added one column to reflect house age.
#
# #### 1.5.8.9 Saving Cleaned df<a id='1.5.8.9_Saving_Cleaned_df'></a>
#
# #### This data frame is cleaned .. so let's save it!!

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df_main_sold_houses_final, 'df_main_sold_houses_final.csv', datapath)

# %% [markdown]
# ## 1.6 Merging 7 DataFrames<a id='1.6_Merging_7_DataFrames'></a>
#
# #### Data Frames Merge:

# %%
# Changing the directory:
os.chdir(r"path/Datasets_cleaned")

# %%
# let's list all the Datasets we need to load for this project: filenames
finals = os.listdir()
finals

# %% [markdown]
# ### 1.6.1 Merge Summary<a id='1.6.1_Merge_Summary'></a>
#
# #### Data Frames to be Merged:
#    1. **df_main_sold_houses_final** is the main DataFrame
#    2. school_df
#    3. df_bart_final
#    4. df_malls_final
#    5. df_median_income
#    6. housing_final_df_v1
#    7. df_universities_final
#
#
#    ![Data_Wrangling](https://user-images.githubusercontent.com/67468718/103494183-52b1c480-4dea-11eb-8673-612746b0d229.JPG)

# %% [markdown]
# ### 1.6.2 Merge dfs on zipcode<a id='1.6.2_Merge_dfs_on_zipcode'></a>

# %%
df_zip_1 = pd.merge(df_main_sold_houses_final,school_df, on='zipcode', how='left')
df_zip_1.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  year_built  days_on_market  \
# 0   905000     3      4  1994         0        2018              80
# 1   645000     2      2  1221      1237        1986             143
# 2   940000     4      2  1928      2660        1981             148
# 3  1036000     3      2  1355      7708        1966              66
# 4  1250000     4      4  3083      3058        2017             143
#
#    price_per_sqft  hoa_month        lat        long  property_age  \
# ...

# %%
df_zip_2 = pd.merge(df_zip_1,df_bart_final, on='zipcode', how='left')
df_zip_2.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  year_built  days_on_market  \
# 0   905000     3      4  1994         0        2018              80
# 1   645000     2      2  1221      1237        1986             143
# 2   940000     4      2  1928      2660        1981             148
# 3  1036000     3      2  1355      7708        1966              66
# 4  1250000     4      4  3083      3058        2017             143
#
#    price_per_sqft  hoa_month        lat        long  property_age  \
# ...

# %%
df_zip_3 = pd.merge(df_zip_2,df_median_income, on='zipcode', how='left')
df_zip_3.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  days_on_market  price_per_sqft  \
# 0   905000     3      4  1994         0  ...              80             454
# 1   645000     2      2  1221      1237  ...             143             528
# 2   940000     4      2  1928      2660  ...             148             488
# 3  1036000     3      2  1355      7708  ...              66             765
# 4  1250000     4      4  3083      3058  ...             143             405
#
# ...

# %%
df_zip_4 = pd.merge(df_zip_3,housing_final_df_v1, on='zipcode', how='left')
df_zip_4.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...        lat        long  \
# 0   905000     3      4  1994         0  ...  37.733978 -121.872736
# 1   645000     2      2  1221      1237  ...  37.663585 -121.864563
# 2   940000     4      2  1928      2660  ...  37.689374 -121.922526
# 3  1036000     3      2  1355      7708  ...  37.680132 -121.915110
# 4  1250000     4      4  3083      3058  ...  37.737748 -121.876525
#
#    property_age  Avg_greatschool_rating_zipcode  school_count_zipcode  \
# ...

# %% [markdown]
# ### 1.6.3 Merge dfs on city<a id='1.6.3_Merge_dfs_on_city'></a>

# %%
df_city_1 = pd.merge(df_zip_4,df_malls_final, on='city', how='left')
df_city_1.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...        long  property_age  \
# 0   905000     3      4  1994         0  ... -121.872736             3
# 1   645000     2      2  1221      1237  ... -121.864563            35
# 2   940000     4      2  1928      2660  ... -121.922526            40
# 3  1036000     3      2  1355      7708  ... -121.915110            55
# 4  1250000     4      4  3083      3058  ... -121.876525             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
df_city_2 = pd.merge(df_city_1,df_universities_final, on='city', how='left')
df_city_2.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %% [markdown]
# #### Let's rename our final Dataframe:

# %%
df = df_city_2

# %%
df.shape
# Out:
# (8926, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8926 entries, 0 to 8925
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   property_name                   8926 non-null   object
#  1   address                         8926 non-null   object
#  2   city                            8926 non-null   object
#  3   state                           8926 non-null   object
#  4   zipcode                         8926 non-null   int64
#  5   price                           8926 non-null   int64
#  6   beds                            8926 non-null   int64
#  7   baths                           8926 non-null   int64
#  8   sqft                            8926 non-null   int64
#  9   lot_size                        8926 non-null   int64
#  10  year_built                      8926 non-null   int64
#  11  days_on_market                  8926 non-null   int64
# ...

# %% [markdown]
# ### 1.6.4 Imputing NANs and Wrong Values<a id='1.6.4_Imputing_NANs_Wrong_Values'></a>
#
# #### let's check NANs in the final df:

# %%
#Let's check the NANs in our Dataframe:
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                 count          %
# universities_count_city          6392  71.611024
# bart_count_zipcode               5967  66.849653
# malls_count_city                 3794  42.505041
# demand_score                      253   2.834416
# supply_score                      253   2.834416
# hotness_score                     253   2.834416
# school_count_zipcode                8   0.089626
# Avg_greatschool_rating_zipcode      8   0.089626
# address                             0   0.000000
# median_income_zipcode_2019          0   0.000000
# property_age                        0   0.000000
# long                                0   0.000000
# lat                                 0   0.000000
# property_name                       0   0.000000
# price_per_sqft                      0   0.000000
# days_on_market                      0   0.000000
# year_built                          0   0.000000
# lot_size                            0   0.000000
# ...

# %% [markdown]
# #### Final df NANs Summary:
#   1. 'universities_count_city' 71.6% Nans means not all cities have university which is True --> Nans will be imputed with 'Zero'.
#   2. 'bart_count_zipcode' 66.8% Nans means not all zipcodes have BARTs which is True --> Nans will be imputed with 'Zero'.
#   3. 'malls_count_city' 66.8% Nans means not all cities have Malls which is True --> Nans will be imputed with 'Zero'.
#   4. NANs at 'demand_score', 'supply_score' and 'hotness_score' will be imputed with mean().
#   5. NANs at 'school_count_zipcode' and 'Avg_greatschool_rating_zipcode' need further investigation ...

# %%
df[df['school_count_zipcode'].isnull()]
# Out:
#                   property_name                   address           city  \
# 3599                Condo/Co-op               3 Mozden Ln  pleasant hill
# 5450  Single Family Residential           4005 Lambert Rd    el sobrante
# 5915                Condo/Co-op     3829 Pacheco Blvd #12       martinez
# 7288  Single Family Residential     2697 Caballo Ranchero         diablo
# 7352  Single Family Residential  2688 Caballo Ranchero Dr         diablo
# 7408  Single Family Residential  2704 Caballo Ranchero Dr         diablo
# 8880                Condo/Co-op     3831 Pacheco Blvd #02       martinez
# 8904                Condo/Co-op     3831 Pacheco Blvd #01       martinez
#
#      state  zipcode    price  beds  baths  sqft  lot_size  ...  property_age  \
# 3599    CA    94563   514000     2      2  1296         0  ...            41
# 5450    CA    94508   620000     2      1  1651         0  ...            75
# 5915    CA    94533   290000     2      1   727     56192  ...            37
# ...

# %%
df[df['Avg_greatschool_rating_zipcode'].isnull()]
# Out:
#                   property_name                   address           city  \
# 3599                Condo/Co-op               3 Mozden Ln  pleasant hill
# 5450  Single Family Residential           4005 Lambert Rd    el sobrante
# 5915                Condo/Co-op     3829 Pacheco Blvd #12       martinez
# 7288  Single Family Residential     2697 Caballo Ranchero         diablo
# 7352  Single Family Residential  2688 Caballo Ranchero Dr         diablo
# 7408  Single Family Residential  2704 Caballo Ranchero Dr         diablo
# 8880                Condo/Co-op     3831 Pacheco Blvd #02       martinez
# 8904                Condo/Co-op     3831 Pacheco Blvd #01       martinez
#
#      state  zipcode    price  beds  baths  sqft  lot_size  ...  property_age  \
# 3599    CA    94563   514000     2      2  1296         0  ...            41
# 5450    CA    94508   620000     2      1  1651         0  ...            75
# 5915    CA    94533   290000     2      1   727     56192  ...            37
# ...

# %% [markdown]
# #### After investigation regarding the NANs at 'school_count_zipcode' and 'Avg_greatschool_rating_zipcode' :
#     All the NANs will be dropped for the following zipcodes: 94508, 94563, 94533 and 94528 (8 rows in total)

# %%
df[df['zipcode'] == 94563]
# Out:
#      property_name      address           city state  zipcode   price  beds  \
# 3599   Condo/Co-op  3 Mozden Ln  pleasant hill    CA    94563  514000     2
#
#       baths  sqft  lot_size  ...  property_age  \
# 3599      2  1296         0  ...            41
#
#       Avg_greatschool_rating_zipcode  school_count_zipcode  \
# 3599                             NaN                   NaN
#
#       bart_count_zipcode  median_income_zipcode_2019  hotness_score  \
# 3599                 1.0                      174952           70.5
#
#       supply_score  demand_score  malls_count_city  universities_count_city
# 3599         70.65         70.36               NaN                      1.0
#
# [1 rows x 26 columns]

# %%
df[df['zipcode'] == 94508]
# Out:
#                   property_name          address         city state  zipcode  \
# 5450  Single Family Residential  4005 Lambert Rd  el sobrante    CA    94508
#
#        price  beds  baths  sqft  lot_size  ...  property_age  \
# 5450  620000     2      1  1651         0  ...            75
#
#       Avg_greatschool_rating_zipcode  school_count_zipcode  \
# 5450                             NaN                   NaN
#
#       bart_count_zipcode  median_income_zipcode_2019  hotness_score  \
# 5450                 NaN                       76248          22.71
#
#       supply_score  demand_score  malls_count_city  universities_count_city
# 5450         39.03          6.39               NaN                      NaN
#
# [1 rows x 26 columns]

# %%
df[df['zipcode'] == 94533]
# Out:
#      property_name                address      city state  zipcode   price  \
# 5915   Condo/Co-op  3829 Pacheco Blvd #12  martinez    CA    94533  290000
# 8880   Condo/Co-op  3831 Pacheco Blvd #02  martinez    CA    94533  275000
# 8904   Condo/Co-op  3831 Pacheco Blvd #01  martinez    CA    94533  275000
#
#       beds  baths  sqft  lot_size  ...  property_age  \
# 5915     2      1   727     56192  ...            37
# 8880     2      1   741     56192  ...            37
# 8904     2      1   741     56192  ...            37
#
#       Avg_greatschool_rating_zipcode  school_count_zipcode  \
# 5915                             NaN                   NaN
# 8880                             NaN                   NaN
# 8904                             NaN                   NaN
#
#       bart_count_zipcode  median_income_zipcode_2019  hotness_score  \
# 5915                 NaN                       59992          87.17
# 8880                 NaN                       59992          87.17
# ...

# %%
df[df['zipcode'] == 94528]
# Out:
#                   property_name                   address    city state  \
# 7288  Single Family Residential     2697 Caballo Ranchero  diablo    CA
# 7352  Single Family Residential  2688 Caballo Ranchero Dr  diablo    CA
# 7408  Single Family Residential  2704 Caballo Ranchero Dr  diablo    CA
#
#       zipcode    price  beds  baths  sqft  lot_size  ...  property_age  \
# 7288    94528  6000000     6      7  6422     67954  ...            67
# 7352    94528  2400000     4      4  3790     68825  ...            55
# 7408    94528  1712500     4      3  2708     60984  ...            32
#
#       Avg_greatschool_rating_zipcode  school_count_zipcode  \
# 7288                             NaN                   NaN
# 7352                             NaN                   NaN
# 7408                             NaN                   NaN
#
#       bart_count_zipcode  median_income_zipcode_2019  hotness_score  \
# 7288                 NaN                      170931            NaN
# ...

# %%
# Get indexes where zipcode=94563:
indexNames = df[df['zipcode'] == 94563].index

# %%
# Delete these row indexes from dataFrame:
df.drop(indexNames , inplace=True)

# %%
# Confirm deleted:
df[df['zipcode'] == 94563]
# Out:
# Empty DataFrame
# Columns: [property_name, address, city, state, zipcode, price, beds, baths, sqft, lot_size, year_built, days_on_market, price_per_sqft, hoa_month, lat, long, property_age, Avg_greatschool_rating_zipcode, school_count_zipcode, bart_count_zipcode, median_income_zipcode_2019, hotness_score, supply_score, demand_score, malls_count_city, universities_count_city]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Get indexes where zipcode=94508:
indexNames = df[df['zipcode'] == 94508].index

# %%
# Delete these row indexes from dataFrame:
df.drop(indexNames , inplace=True)

# %%
# Confirm deleted:
df[df['zipcode'] == 94508]
# Out:
# Empty DataFrame
# Columns: [property_name, address, city, state, zipcode, price, beds, baths, sqft, lot_size, year_built, days_on_market, price_per_sqft, hoa_month, lat, long, property_age, Avg_greatschool_rating_zipcode, school_count_zipcode, bart_count_zipcode, median_income_zipcode_2019, hotness_score, supply_score, demand_score, malls_count_city, universities_count_city]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Get indexes where zipcode=94533:
indexNames = df[df['zipcode'] == 94533].index

# %%
# Delete these row indexes from dataFrame:
df.drop(indexNames , inplace=True)

# %%
# Confirm deleted:
df[df['zipcode'] == 94533]
# Out:
# Empty DataFrame
# Columns: [property_name, address, city, state, zipcode, price, beds, baths, sqft, lot_size, year_built, days_on_market, price_per_sqft, hoa_month, lat, long, property_age, Avg_greatschool_rating_zipcode, school_count_zipcode, bart_count_zipcode, median_income_zipcode_2019, hotness_score, supply_score, demand_score, malls_count_city, universities_count_city]
# Index: []
#
# [0 rows x 26 columns]

# %%
# Get indexes where zipcode=94528:
indexNames = df[df['zipcode'] == 94528].index

# %%
# Delete these row indexes from dataFrame:
df.drop(indexNames , inplace=True)

# %%
# Confirm deleted:
df[df['zipcode'] == 94528]
# Out:
# Empty DataFrame
# Columns: [property_name, address, city, state, zipcode, price, beds, baths, sqft, lot_size, year_built, days_on_market, price_per_sqft, hoa_month, lat, long, property_age, Avg_greatschool_rating_zipcode, school_count_zipcode, bart_count_zipcode, median_income_zipcode_2019, hotness_score, supply_score, demand_score, malls_count_city, universities_count_city]
# Index: []
#
# [0 rows x 26 columns]

# %% [markdown]
# #### NANs at 'school_count_zipcode' and 'Avg_greatschool_rating_zipcode' are cleaned up ...
#
# #### Finally lets cleanup below:
#
#   1. 'universities_count_city' 71.6% Nans means not all cities have university which is True --> Nans will be imputed with 'Zero'.
#   2. 'bart_count_zipcode' 66.8% Nans means not all zipcodes have BARTs which is True --> Nans will be imputed with 'Zero'.
#   3. 'malls_count_city' 66.8% Nans means not all cities have Malls which is True --> Nans will be imputed with 'Zero'.
#   4. NANs at 'demand_score', 'supply_score' and 'hotness_score' will be imputed with mean().

# %%
# First for 'universities_count_city','bart_count_zipcode' and 'malls_count_city' let's impute the missing values with the "0":
df_imputed = df.fillna({'universities_count_city': 0, 'bart_count_zipcode': 0, 'malls_count_city': 0})
df_imputed.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
# Finally for 'demand_score', 'supply_score' and 'hotness_score' let's impute the missing values with the mean:
demand_score_mean = df_imputed['demand_score'].mean()
supply_score_mean = df_imputed['supply_score'].mean()
hotness_score_mean = df_imputed['hotness_score'].mean()
df_imputed_v = df_imputed.fillna({'demand_score': demand_score_mean, 
                                  'supply_score': supply_score_mean, 
                                  'hotness_score': hotness_score_mean})
df_imputed_v.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
#Let's check the NANs in our Dataframe:
missing = pd.concat([df.isnull().sum(), 100 * df.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                 count          %
# universities_count_city          6385  71.596771
# bart_count_zipcode               5960  66.831128
# malls_count_city                 3786  42.453465
# demand_score                      250   2.803319
# supply_score                      250   2.803319
# hotness_score                     250   2.803319
# address                             0   0.000000
# median_income_zipcode_2019          0   0.000000
# school_count_zipcode                0   0.000000
# Avg_greatschool_rating_zipcode      0   0.000000
# property_age                        0   0.000000
# long                                0   0.000000
# lat                                 0   0.000000
# property_name                       0   0.000000
# price_per_sqft                      0   0.000000
# days_on_market                      0   0.000000
# year_built                          0   0.000000
# lot_size                            0   0.000000
# ...

# %%
# First for 'universities_count_city','bart_count_zipcode' and 'malls_count_city' let's impute the missing values with the "0":
df_imputed = df.fillna({'universities_count_city': 0, 'bart_count_zipcode': 0, 'malls_count_city': 0})
df_imputed.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
# Finally for 'demand_score', 'supply_score' and 'hotness_score' let's impute the missing values with the mean:
demand_score_mean = df_imputed['demand_score'].mean()
supply_score_mean = df_imputed['supply_score'].mean()
hotness_score_mean = df_imputed['hotness_score'].mean()
df_imputed_v = df_imputed.fillna({'demand_score': demand_score_mean, 'supply_score': supply_score_mean, 'hotness_score': hotness_score_mean})
df_imputed_v.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
#Let's check the NANs in our Dataframe:
missing = pd.concat([df_imputed_v.isnull().sum(), 100 * df_imputed_v.isnull().mean()], axis=1)
missing.columns=['count', '%']
missing.sort_values(by='count', ascending=False)
# Out:
#                                 count    %
# property_name                       0  0.0
# address                             0  0.0
# malls_count_city                    0  0.0
# demand_score                        0  0.0
# supply_score                        0  0.0
# hotness_score                       0  0.0
# median_income_zipcode_2019          0  0.0
# bart_count_zipcode                  0  0.0
# school_count_zipcode                0  0.0
# Avg_greatschool_rating_zipcode      0  0.0
# property_age                        0  0.0
# long                                0  0.0
# lat                                 0  0.0
# hoa_month                           0  0.0
# price_per_sqft                      0  0.0
# days_on_market                      0  0.0
# year_built                          0  0.0
# lot_size                            0  0.0
# sqft                                0  0.0
# baths                               0  0.0
# beds                                0  0.0
# ...

# %% [markdown]
# #### In or Final DataFrame we have now cleaned up all the NANs

# %%
# Let's rename the dataframe:
df = df_imputed_v

# %%
df.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %%
df.shape
# Out:
# (8918, 26)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8918 entries, 0 to 8925
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   property_name                   8918 non-null   object
#  1   address                         8918 non-null   object
#  2   city                            8918 non-null   object
#  3   state                           8918 non-null   object
#  4   zipcode                         8918 non-null   int64
#  5   price                           8918 non-null   int64
#  6   beds                            8918 non-null   int64
#  7   baths                           8918 non-null   int64
#  8   sqft                            8918 non-null   int64
#  9   lot_size                        8918 non-null   int64
#  10  year_built                      8918 non-null   int64
#  11  days_on_market                  8918 non-null   int64
# ...

# %% [markdown]
# ### 1.6.5 Correcting Data Types<a id='1.6.5_Correcting_Data_Types'></a>
#
# #### let's change datatype at 'Avg_greatschool_rating_zipcode', 'school_count_zipcode', 'bart_count_zipcode', 'malls_count_city' and 'universities_count_city' from float to int:

# %%
df['Avg_greatschool_rating_zipcode'] = df['Avg_greatschool_rating_zipcode'].astype('int64')

# %%
df['school_count_zipcode'] = df['school_count_zipcode'].astype('int64')

# %%
df['bart_count_zipcode'] = df['bart_count_zipcode'].astype('int64')

# %%
df['malls_count_city'] = df['malls_count_city'].astype('int64')

# %%
df['universities_count_city'] = df['universities_count_city'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8918 entries, 0 to 8925
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   property_name                   8918 non-null   object
#  1   address                         8918 non-null   object
#  2   city                            8918 non-null   object
#  3   state                           8918 non-null   object
#  4   zipcode                         8918 non-null   int64
#  5   price                           8918 non-null   int64
#  6   beds                            8918 non-null   int64
#  7   baths                           8918 non-null   int64
#  8   sqft                            8918 non-null   int64
#  9   lot_size                        8918 non-null   int64
#  10  year_built                      8918 non-null   int64
#  11  days_on_market                  8918 non-null   int64
# ...

# %%
df.head()
# Out:
#                property_name             address        city state  zipcode  \
# 0                Condo/Co-op   6985 Calistoga Ln      dublin    CA    94568
# 1                  Townhouse  270 Birch Creek Dr  pleasanton    CA    94566
# 2                Condo/Co-op   5324 Brookside Ct  pleasanton    CA    94588
# 3  Single Family Residential   4385 Clovewood Ln  pleasanton    CA    94588
# 4  Single Family Residential      4273 Trolan Ln      dublin    CA    94568
#
#      price  beds  baths  sqft  lot_size  ...  property_age  \
# 0   905000     3      4  1994         0  ...             3
# 1   645000     2      2  1221      1237  ...            35
# 2   940000     4      2  1928      2660  ...            40
# 3  1036000     3      2  1355      7708  ...            55
# 4  1250000     4      4  3083      3058  ...             4
#
#    Avg_greatschool_rating_zipcode  school_count_zipcode  bart_count_zipcode  \
# ...

# %% [markdown]
# #### Let's save df our final DataFrame:

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df, 'df_final.csv', datapath)

# %%
# Let's visulize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df['price'], kde=True, bins=10)
ax.set_title('House Prices in North CA')
plt.grid(True)

# %% [markdown]
# #### looks like we have something really off in the Price column so let's investigate.

# %%
df.price.sort_values(ascending=False)
# Out:
# 5558    665000000
# 2452     39988000
# 2493     20000000
# 7261     19000000
# 2562     17000000
#           ...
# 638        140000
# 4170       135000
# 3842        85000
# 5735        80000
# 3023         1600
# Name: price, Length: 8918, dtype: int64

# %% [markdown]
# #### WOW, ok $665,000,000 looks like we have a wrong value, so let's investigate further

# %%
df[df['price'] == 665000000]
# Out:
#                   property_name          address         city state  zipcode  \
# 5558  Single Family Residential  342 Shirley Vis  el sobrante    CA    94803
#
#           price  beds  baths  sqft  lot_size  ...  property_age  \
# 5558  665000000     3      2  1122      6000  ...            65
#
#       Avg_greatschool_rating_zipcode  school_count_zipcode  \
# 5558                               3                     7
#
#       bart_count_zipcode  median_income_zipcode_2019  hotness_score  \
# 5558                   0                       80272          87.24
#
#       supply_score  demand_score  malls_count_city  universities_count_city
# 5558         86.68         87.79                 0                        0
#
# [1 rows x 26 columns]

# %% [markdown]
# #### After checking the price for the house in the address the sold price was $665,000  so let's fix this value.

# %%
# so let's fix the price:
df.at[5558,'price'] = 665000

# %%
df.price.sort_values(ascending=False)
# Out:
# 2452    39988000
# 2493    20000000
# 7261    19000000
# 2562    17000000
# 2426    16000000
#           ...
# 638       140000
# 4170      135000
# 3842       85000
# 5735       80000
# 3023        1600
# Name: price, Length: 8918, dtype: int64

# %%
# Let's visulize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df['price'], kde=True, bins=10)
ax.set_title('House Prices in North CA')
plt.grid(True)

# %% [markdown]
# ### 1.6.6 Saving Final df<a id='1.6.6_Saving_Final_df'></a>

# %%
# save the data to a new csv file
datapath = 'path/Datasets_cleaned'
save_file(df, 'df_final_v1.csv', datapath)

# %% [markdown]
# ### 1.6.7 Visualization<a id='1.6.7_Visualization'></a>

# %%
# Let's visulize the dataframe:
f, ax = plt.subplots(figsize = (10,6))
ax = sns.histplot(df['price'], kde=True, bins=100)
ax.set_title('House Prices in North CA')
plt.grid(True)

# %%
# Set up the matplotlib figure
plt.figure(figsize=(25,5))
plt.subplot(121)
sns.distplot(df['price'],kde=False)
plt.xlabel('Price')
plt.axis([0,10000000,0,5000])
plt.subplot(122)
sns.distplot(np.log(df['price']),kde=False)
plt.xlabel('Log (price)')
plt.axis([12,16,0,1600])
# Out:
# C:\Users\aktha\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# (12.0, 16.0, 0.0, 1600.0)

# %% [markdown]
# ## 1.7 Target Features<a id='1.7_Target_Features'></a>

# %%
df.hist(figsize=(25, 15))
plt.subplots_adjust(hspace=1);

# %%
sns.jointplot(x="Avg_greatschool_rating_zipcode", y="price", data=df,
                  kind="reg", truncate=False,
                  #xlim=(200000, 4000000), ylim=(0, 11),
                  color="m", height=8)
